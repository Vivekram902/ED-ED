# %% [markdown]
# download nltk_data folder from here : https://www.dropbox.com/sh/27t8ijq0elot8cw/AAAc8oe0d_mdtAhi3xk51ThEa?dl=0

# %% [markdown]
# # Example of Collecting Data from multiple files

# %% [markdown]
# download reuters_data from here : https://www.dropbox.com/sh/865xeu4xwbyo2yt/AACd0pQEbeOSfvNjiV7aur4Ka?dl=0

# %%
import os
import pandas as pd
import nltk
path="D:/Data/Reuters Data/"
files=os.listdir(path)

# %%
f=open(path+'training_money-fx_3593.txt','r',encoding='latin-1')

# %%
text=""
for line in f:
    if line.strip()=="":continue
    else:
        text+=' '+line.strip()
print(text)
f.close()
# Out:
#  HUNGARY HOPES DEVALUATION WILL END TRADE DEFICIT National Bank of Hungary first vice-president Janos Fekete said he hoped a planned eight pct devaluation of the forint will spur exports and redress last year's severe trade deficit with the West. Fekete told Reuters in an interview Hungary must achieve at least equilibrium on its hard currency trade. "It is useful to have a devaluation," he said. "There is now a real push to our exports and a bit of a curb to our imports." The official news agency MTI said today Hungary would devalue by eight pct and it expected the new rates to be announced later today. Fekete said the rates would come into effect tomorrow. He said one reason for the devaluation was that Hungary had a higher rate of inflation over the past two years than its main partners (around eight pct in 1985 and between five and 5.5 pct in 1986). This was partly an after-effect of action Hungary took to prevent inflation from soaring during the oil price shocks of the 1970s, he added. Hungary devalued by a similar amount last September and by between three and four pct early last year. But the country's hard currency trade balance nevertheless fell into a deficit of 539.4 mln dlrs from a surplus of 295.3 mln in 1986 and 1.2 billion in 1985. Fekete said Hungary was hoping for a hard currency trade surplus of between 200 and 300 mln dlrs this year, but that a more likely outcome would be closer to equilibrium on total hard currency trade of around 10 billion dlrs. One Western commercial attache here said: "Devaluation of itself will not change anything. It will only be useful if they also make efforts to restructure industry and improve the quality of their export goods." Fekete said he hoped to raise credits on good terms this year to invest in restructuring industry. It would be his role to persuade international banks to cooperate in this process. He noted Hungary had been given an AA rating enabling it to raise money on the Japanese Samurai bond market. Hungary's net hard currency debt soared to 7.79 billion dlrs last year from 5.01 billion in 1985, partly because of a current account deficit of 1.42 billion dlrs and partly because the fall in the dollar increased the dollar value of debt denominated in marks or yen. He said he feared net debt would also rise slightly this year, but he was in favour of borrowing for the purpose of modernisation. "I am for credits to invest for that purpose," he said. "I am against credits for consumption." He forecast gross domestic product growth of two pct this year, from one pct in 1986. Fekete said Hungary would continue to restructure its debt profile by prepaying high interest shorter and medium term loans with cheaper long term money for which it was looking more and more to the fixed interest rate bond market, where he considered rates to be low. Hard currency foreign exchange reserves would stay at around 3.5 billion dlrs, he said. On the budget deficit, which tripled to a provisional 47 billion forints last year after quadrupling in 1985, Fekete said the finance ministry was working out measures to reduce an approved target deficit for this year of 43.8 billion forints to between 30 and 35 billion forints.

# %%
files
# Out:
# ['training_crude_10011.txt',
#  'training_crude_10078.txt',
#  'training_crude_10080.txt',
#  'training_crude_10106.txt',
#  'training_crude_10168.txt',
#  'training_crude_10190.txt',
#  'training_crude_10192.txt',
#  'training_crude_10200.txt',
#  'training_crude_10228.txt',
#  'training_crude_1026.txt',
#  'training_crude_10268.txt',
#  'training_crude_10395.txt',
#  'training_crude_10406.txt',
#  'training_crude_10452.txt',
#  'training_crude_10539.txt',
#  'training_crude_10567.txt',
#  'training_crude_10588.txt',
#  'training_crude_10620.txt',
#  'training_crude_10621.txt',
#  'training_crude_10627.txt',
#  'training_crude_10632.txt',
#  'training_crude_10641.txt',
#  'training_crude_10669.txt',
#  'training_crude_10693.txt',
#  'training_crude_10750.txt',
#  'training_crude_10797.txt',
#  'training_crude_10845.txt',
#  'training_crude_10873.txt',
#  'training_crude_10947.txt',
#  'training_crude_11007.txt',
#  'training_crude_11025.txt',
#  'training_crude_11100.txt',
#  'training_crude_11118.txt',
#  'training_crude_11149.txt',
#  'training_crude_11213.txt',
#  'training_crude_11231.txt',
#  'training_crude_11350.txt',
#  'training_crude_11388.txt',
#  'training_crude_11403.txt',
#  'training_crude_11421.txt',
#  'training_crude_11444.txt',
#  'training_crude_11455.txt',
#  'training_crude_11491.txt',
#  'training_crude_11559.txt',
#  'training_crude_11632.txt',
#  'training_crude_11639.txt',
#  'training_crude_11699.txt',
#  'training_crude_11723.txt',
#  'training_crude_11731.txt',
#  'training_crude_12267.txt',
#  'training_crude_12286.txt',
#  'training_crude_12371.txt',
#  'training_crude_12503.txt',
#  'training_crude_12533.txt',
#  'training_crude_127.txt',
#  'training_crude_12775.txt',
#  'training_crude_12803.txt',
#  'training_crude_12940.txt',
#  'training_crude_1306.txt',
#  'training_crude_13096.txt',
#  'training_crude_13102.txt',
#  'training_crude_13115.txt',
#  'training_crude_13142.txt',
#  'training_crude_13184.txt',
#  'training_crude_13200.txt',
#  'training_crude_1324.txt',
#  'training_crude_13256.txt',
#  'training_crude_13266.txt',
#  'training_crude_1331.txt',
#  'training_crude_1335.txt',
#  'training_crude_1343.txt',
#  'training_crude_13542.txt',
#  'training_crude_13611.txt',
#  'training_crude_13633.txt',
#  'training_crude_1387.txt',
#  'training_crude_13963.txt',
#  'training_crude_14211.txt',
#  'training_crude_14395.txt',
#  'training_crude_144.txt',
#  'training_crude_14698.txt',
#  'training_crude_14704.txt',
#  'training_crude_14709.txt',
#  'training_crude_14732.txt',
#  'training_crude_1521.txt',
#  'training_crude_1556.txt',
#  'training_crude_1616.txt',
#  'training_crude_1661.txt',
#  'training_crude_1686.txt',
#  'training_crude_1692.txt',
#  'training_crude_1709.txt',
#  'training_crude_1711.txt',
#  'training_crude_1799.txt',
#  'training_crude_1851.txt',
#  'training_crude_1856.txt',
#  'training_crude_1875.txt',
#  'training_crude_1878.txt',
#  'training_crude_189.txt',
#  'training_crude_1904.txt',
#  'training_crude_1909.txt',
#  'training_crude_191.txt',
#  'training_crude_194.txt',
#  'training_crude_1948.txt',
#  'training_crude_1980.txt',
#  'training_crude_1990.txt',
#  'training_crude_2004.txt',
#  'training_crude_2007.txt',
#  'training_crude_2046.txt',
#  'training_crude_2061.txt',
#  'training_crude_211.txt',
#  'training_crude_2121.txt',
#  'training_crude_2174.txt',
#  'training_crude_2175.txt',
#  'training_crude_2187.txt',
#  'training_crude_2231.txt',
#  'training_crude_236.txt',
#  'training_crude_237.txt',
#  'training_crude_2383.txt',
#  'training_crude_242.txt',
#  'training_crude_2449.txt',
#  'training_crude_246.txt',
#  'training_crude_248.txt',
#  'training_crude_2511.txt',
#  'training_crude_2515.txt',
#  'training_crude_2517.txt',
#  'training_crude_2522.txt',
#  'training_crude_2530.txt',
#  'training_crude_2585.txt',
#  'training_crude_2688.txt',
#  'training_crude_273.txt',
#  'training_crude_2767.txt',
#  'training_crude_2775.txt',
#  'training_crude_2838.txt',
#  'training_crude_2925.txt',
#  'training_crude_2957.txt',
#  'training_crude_2970.txt',
#  'training_crude_2973.txt',
#  'training_crude_2998.txt',
#  'training_crude_3003.txt',
#  'training_crude_3015.txt',
#  'training_crude_3017.txt',
#  'training_crude_3048.txt',
#  'training_crude_3065.txt',
#  'training_crude_3115.txt',
#  'training_crude_3145.txt',
#  'training_crude_3146.txt',
#  'training_crude_3162.txt',
#  'training_crude_3169.txt',
#  'training_crude_3174.txt',
#  'training_crude_3189.txt',
#  'training_crude_3204.txt',
#  'training_crude_3303.txt',
#  'training_crude_3332.txt',
#  'training_crude_3342.txt',
#  'training_crude_3354.txt',
#  'training_crude_3364.txt',
#  'training_crude_3389.txt',
#  'training_crude_3430.txt',
#  'training_crude_3452.txt',
#  'training_crude_3455.txt',
#  'training_crude_349.txt',
#  'training_crude_3507.txt',
#  'training_crude_3509.txt',
#  'training_crude_352.txt',
#  'training_crude_353.txt',
#  'training_crude_3556.txt',
#  'training_crude_3563.txt',
#  'training_crude_3571.txt',
#  'training_crude_3592.txt',
#  'training_crude_3594.txt',
#  'training_crude_3609.txt',
#  'training_crude_368.txt',
#  'training_crude_3798.txt',
#  'training_crude_3843.txt',
#  'training_crude_3869.txt',
#  'training_crude_3906.txt',
#  'training_crude_3959.txt',
#  'training_crude_3976.txt',
#  'training_crude_3980.txt',
#  'training_crude_3985.txt',
#  'training_crude_3995.txt',
#  'training_crude_4016.txt',
#  'training_crude_4028.txt',
#  'training_crude_4039.txt',
#  'training_crude_4041.txt',
#  'training_crude_4125.txt',
#  'training_crude_4129.txt',
#  'training_crude_4162.txt',
#  'training_crude_4171.txt',
#  'training_crude_4174.txt',
#  'training_crude_4232.txt',
#  'training_crude_4246.txt',
#  'training_crude_4315.txt',
#  'training_crude_4333.txt',
#  'training_crude_4340.txt',
#  'training_crude_4365.txt',
#  'training_crude_4367.txt',
#  'training_crude_4386.txt',
#  'training_crude_4425.txt',
#  'training_crude_4429.txt',
#  'training_crude_4445.txt',
#  'training_crude_4453.txt',
#  'training_crude_4462.txt',
#  'training_crude_4466.txt',
#  'training_crude_4467.txt',
#  'training_crude_4474.txt',
#  'training_crude_4481.txt',
#  'training_crude_4525.txt',
#  'training_crude_4558.txt',
#  'training_crude_4569.txt',
#  'training_crude_4576.txt',
#  'training_crude_4578.txt',
#  'training_crude_4584.txt',
#  'training_crude_459.txt',
#  'training_crude_4590.txt',
#  'training_crude_4593.txt',
#  'training_crude_4600.txt',
#  'training_crude_4604.txt',
#  'training_crude_4609.txt',
#  'training_crude_4658.txt',
#  'training_crude_4662.txt',
#  'training_crude_4664.txt',
#  'training_crude_4689.txt',
#  'training_crude_4713.txt',
#  'training_crude_4714.txt',
#  'training_crude_4742.txt',
#  'training_crude_4831.txt',
#  'training_crude_4848.txt',
#  'training_crude_4867.txt',
#  'training_crude_489.txt',
#  'training_crude_4951.txt',
#  'training_crude_4953.txt',
#  'training_crude_4962.txt',
#  'training_crude_4983.txt',
#  'training_crude_502.txt',
#  'training_crude_5037.txt',
#  'training_crude_5061.txt',
#  'training_crude_511.txt',
#  'training_crude_5116.txt',
#  'training_crude_5118.txt',
#  'training_crude_5119.txt',
#  'training_crude_5123.txt',
#  'training_crude_5125.txt',
#  'training_crude_5150.txt',
#  'training_crude_5156.txt',
#  'training_crude_5166.txt',
#  'training_crude_5167.txt',
#  'training_crude_5171.txt',
#  'training_crude_5244.txt',
#  'training_crude_5268.txt',
#  'training_crude_5270.txt',
#  'training_crude_5273.txt',
#  'training_crude_5281.txt',
#  'training_crude_543.txt',
#  'training_crude_5542.txt',
#  'training_crude_5553.txt',
#  'training_crude_5630.txt',
#  'training_crude_5683.txt',
#  'training_crude_5796.txt',
#  'training_crude_5852.txt',
#  'training_crude_5866.txt',
#  'training_crude_6023.txt',
#  'training_crude_6060.txt',
#  'training_crude_6086.txt',
#  'training_crude_6111.txt',
#  'training_crude_6119.txt',
#  'training_crude_6125.txt',
#  'training_crude_6159.txt',
#  'training_crude_6163.txt',
#  'training_crude_6166.txt',
#  'training_crude_6169.txt',
#  'training_crude_6177.txt',
#  'training_crude_6184.txt',
#  'training_crude_6201.txt',
#  'training_crude_6208.txt',
#  'training_crude_6264.txt',
#  'training_crude_6294.txt',
#  'training_crude_6301.txt',
#  'training_crude_6348.txt',
#  'training_crude_6404.txt',
#  'training_crude_6413.txt',
#  'training_crude_6432.txt',
#  'training_crude_6578.txt',
#  'training_crude_6598.txt',
#  'training_crude_6606.txt',
#  'training_crude_6652.txt',
#  'training_crude_6656.txt',
#  'training_crude_6722.txt',
#  'training_crude_6742.txt',
#  'training_crude_6746.txt',
#  'training_crude_6760.txt',
#  'training_crude_6791.txt',
#  'training_crude_6871.txt',
#  'training_crude_6876.txt',
#  'training_crude_6893.txt',
#  'training_crude_6905.txt',
#  'training_crude_6913.txt',
#  'training_crude_6996.txt',
#  'training_crude_704.txt',
#  'training_crude_7067.txt',
#  'training_crude_708.txt',
#  'training_crude_7097.txt',
#  'training_crude_7150.txt',
#  'training_crude_7152.txt',
#  'training_crude_7174.txt',
#  'training_crude_7287.txt',
#  'training_crude_7355.txt',
#  'training_crude_7423.txt',
#  'training_crude_7496.txt',
#  'training_crude_7528.txt',
#  'training_crude_7529.txt',
#  'training_crude_7611.txt',
#  'training_crude_7618.txt',
#  'training_crude_7639.txt',
#  'training_crude_7684.txt',
#  'training_crude_7742.txt',
#  'training_crude_7854.txt',
#  'training_crude_791.txt',
#  'training_crude_8015.txt',
#  'training_crude_8041.txt',
#  'training_crude_8069.txt',
#  'training_crude_8089.txt',
#  'training_crude_8100.txt',
#  'training_crude_8117.txt',
#  'training_crude_8131.txt',
#  'training_crude_8134.txt',
#  'training_crude_8160.txt',
#  'training_crude_8167.txt',
#  'training_crude_8188.txt',
#  'training_crude_8209.txt',
#  'training_crude_8210.txt',
#  'training_crude_8288.txt',
#  'training_crude_835.txt',
#  'training_crude_8402.txt',
#  'training_crude_8405.txt',
#  'training_crude_8421.txt',
#  'training_crude_8440.txt',
#  'training_crude_8478.txt',
#  'training_crude_8493.txt',
#  'training_crude_8516.txt',
#  'training_crude_8553.txt',
#  'training_crude_8598.txt',
#  'training_crude_8600.txt',
#  'training_crude_8606.txt',
#  'training_crude_8610.txt',
#  'training_crude_8623.txt',
#  'training_crude_8630.txt',
#  'training_crude_8672.txt',
#  'training_crude_8675.txt',
#  'training_crude_873.txt',
#  'training_crude_8749.txt',
#  'training_crude_8755.txt',
#  'training_crude_8765.txt',
#  'training_crude_8812.txt',
#  'training_crude_8815.txt',
#  'training_crude_8820.txt',
#  'training_crude_8835.txt',
#  'training_crude_8856.txt',
#  'training_crude_8882.txt',
#  'training_crude_8914.txt',
#  'training_crude_8959.txt',
#  'training_crude_8964.txt',
#  'training_crude_8971.txt',
#  'training_crude_9031.txt',
#  'training_crude_9039.txt',
#  'training_crude_9065.txt',
#  'training_crude_9155.txt',
#  'training_crude_918.txt',
#  'training_crude_9208.txt',
#  'training_crude_9253.txt',
#  'training_crude_9279.txt',
#  'training_crude_9293.txt',
#  'training_crude_930.txt',
#  'training_crude_9436.txt',
#  'training_crude_9445.txt',
#  'training_crude_945.txt',
#  'training_crude_952.txt',
#  'training_crude_9527.txt',
#  'training_crude_9583.txt',
#  'training_crude_9614.txt',
#  'training_crude_9634.txt',
#  'training_crude_9639.txt',
#  'training_crude_9650.txt',
#  'training_crude_9674.txt',
#  'training_crude_9718.txt',
#  'training_crude_9801.txt',
#  'training_crude_9849.txt',
#  'training_crude_988.txt',
#  'training_crude_9913.txt',
#  'training_crude_9947.txt',
#  'training_money-fx_10048.txt',
#  'training_money-fx_10075.txt',
#  'training_money-fx_1008.txt',
#  'training_money-fx_10081.txt',
#  'training_money-fx_10091.txt',
#  'training_money-fx_10136.txt',
#  'training_money-fx_10191.txt',
#  'training_money-fx_10263.txt',
#  'training_money-fx_10308.txt',
#  'training_money-fx_10321.txt',
#  'training_money-fx_10323.txt',
#  'training_money-fx_10337.txt',
#  'training_money-fx_10340.txt',
#  'training_money-fx_10344.txt',
#  'training_money-fx_10354.txt',
#  'training_money-fx_10356.txt',
#  'training_money-fx_10357.txt',
#  'training_money-fx_10358.txt',
#  'training_money-fx_10359.txt',
#  'training_money-fx_10364.txt',
#  'training_money-fx_10368.txt',
#  'training_money-fx_10370.txt',
#  'training_money-fx_10382.txt',
#  'training_money-fx_10416.txt',
#  'training_money-fx_10418.txt',
#  'training_money-fx_10475.txt',
#  'training_money-fx_10503.txt',
#  'training_money-fx_10546.txt',
#  'training_money-fx_10606.txt',
#  'training_money-fx_10617.txt',
#  'training_money-fx_10618.txt',
#  'training_money-fx_10622.txt',
#  'training_money-fx_10633.txt',
#  'training_money-fx_10636.txt',
#  'training_money-fx_10638.txt',
#  'training_money-fx_10650.txt',
#  'training_money-fx_10651.txt',
#  'training_money-fx_10652.txt',
#  'training_money-fx_10653.txt',
#  'training_money-fx_10654.txt',
#  'training_money-fx_10657.txt',
#  'training_money-fx_10658.txt',
#  'training_money-fx_10659.txt',
#  'training_money-fx_10660.txt',
#  'training_money-fx_10661.txt',
#  'training_money-fx_10679.txt',
#  'training_money-fx_10681.txt',
#  'training_money-fx_10684.txt',
#  'training_money-fx_10689.txt',
#  'training_money-fx_10696.txt',
#  'training_money-fx_10704.txt',
#  'training_money-fx_10710.txt',
#  'training_money-fx_10718.txt',
#  'training_money-fx_10731.txt',
#  'training_money-fx_10734.txt',
#  'training_money-fx_10736.txt',
#  'training_money-fx_10749.txt',
#  'training_money-fx_10751.txt',
#  'training_money-fx_10755.txt',
#  'training_money-fx_10756.txt',
#  'training_money-fx_10762.txt',
#  'training_money-fx_10766.txt',
#  'training_money-fx_10769.txt',
#  'training_money-fx_10770.txt',
#  'training_money-fx_10771.txt',
#  'training_money-fx_10773.txt',
#  'training_money-fx_10774.txt',
#  'training_money-fx_10780.txt',
#  'training_money-fx_10782.txt',
#  'training_money-fx_10796.txt',
#  'training_money-fx_10804.txt',
#  'training_money-fx_10807.txt',
#  'training_money-fx_10808.txt',
#  'training_money-fx_10809.txt',
#  'training_money-fx_10859.txt',
#  'training_money-fx_10864.txt',
#  'training_money-fx_1088.txt',
#  'training_money-fx_10913.txt',
#  'training_money-fx_11000.txt',
#  'training_money-fx_11059.txt',
#  'training_money-fx_11103.txt',
#  'training_money-fx_1112.txt',
#  'training_money-fx_11120.txt',
#  'training_money-fx_11135.txt',
#  'training_money-fx_11193.txt',
#  'training_money-fx_11200.txt',
#  'training_money-fx_11203.txt',
#  'training_money-fx_11209.txt',
#  'training_money-fx_11212.txt',
#  'training_money-fx_11228.txt',
#  'training_money-fx_11234.txt',
#  'training_money-fx_11238.txt',
#  'training_money-fx_11244.txt',
#  'training_money-fx_11256.txt',
#  'training_money-fx_11263.txt',
#  'training_money-fx_11281.txt',
#  'training_money-fx_11284.txt',
#  'training_money-fx_11297.txt',
#  'training_money-fx_11322.txt',
#  'training_money-fx_11365.txt',
#  'training_money-fx_11417.txt',
#  'training_money-fx_11430.txt',
#  'training_money-fx_11447.txt',
#  'training_money-fx_11450.txt',
#  'training_money-fx_1154.txt',
#  'training_money-fx_11551.txt',
#  'training_money-fx_11734.txt',
#  'training_money-fx_11753.txt',
#  'training_money-fx_11764.txt',
#  'training_money-fx_11772.txt',
#  'training_money-fx_11774.txt',
#  'training_money-fx_11776.txt',
#  'training_money-fx_11783.txt',
#  'training_money-fx_11794.txt',
#  'training_money-fx_11798.txt',
#  'training_money-fx_11820.txt',
#  'training_money-fx_11832.txt',
#  'training_money-fx_11844.txt',
#  'training_money-fx_11864.txt',
#  'training_money-fx_11938.txt',
#  'training_money-fx_11944.txt',
#  'training_money-fx_11946.txt',
#  'training_money-fx_11972.txt',
#  'training_money-fx_12121.txt',
#  'training_money-fx_12136.txt',
#  'training_money-fx_12145.txt',
#  'training_money-fx_12177.txt',
#  'training_money-fx_12183.txt',
#  'training_money-fx_12396.txt',
#  'training_money-fx_12406.txt',
#  'training_money-fx_12410.txt',
#  'training_money-fx_12413.txt',
#  'training_money-fx_12416.txt',
#  'training_money-fx_12418.txt',
#  'training_money-fx_12422.txt',
#  'training_money-fx_12437.txt',
#  'training_money-fx_12447.txt',
#  'training_money-fx_12453.txt',
#  'training_money-fx_12456.txt',
#  'training_money-fx_12470.txt',
#  'training_money-fx_12471.txt',
#  'training_money-fx_12494.txt',
#  'training_money-fx_12501.txt',
#  'training_money-fx_12522.txt',
#  'training_money-fx_12523.txt',
#  'training_money-fx_12554.txt',
#  'training_money-fx_12588.txt',
#  'training_money-fx_12593.txt',
#  'training_money-fx_12741.txt',
#  'training_money-fx_12745.txt',
#  'training_money-fx_12780.txt',
#  'training_money-fx_12785.txt',
#  'training_money-fx_12789.txt',
#  'training_money-fx_12791.txt',
#  'training_money-fx_12795.txt',
#  'training_money-fx_12801.txt',
#  'training_money-fx_12806.txt',
#  'training_money-fx_12812.txt',
#  'training_money-fx_12815.txt',
#  'training_money-fx_12819.txt',
#  'training_money-fx_12840.txt',
#  'training_money-fx_12842.txt',
#  'training_money-fx_12877.txt',
#  'training_money-fx_12923.txt',
#  'training_money-fx_13053.txt',
#  'training_money-fx_13243.txt',
#  'training_money-fx_13244.txt',
#  'training_money-fx_13245.txt',
#  'training_money-fx_13261.txt',
#  'training_money-fx_13270.txt',
#  'training_money-fx_13315.txt',
#  'training_money-fx_13398.txt',
#  'training_money-fx_13404.txt',
#  'training_money-fx_13512.txt',
#  'training_money-fx_13524.txt',
#  'training_money-fx_13530.txt',
#  'training_money-fx_13531.txt',
#  'training_money-fx_13544.txt',
#  'training_money-fx_13552.txt',
#  'training_money-fx_13660.txt',
#  'training_money-fx_13739.txt',
#  'training_money-fx_13831.txt',
#  'training_money-fx_13869.txt',
#  'training_money-fx_13903.txt',
#  'training_money-fx_13919.txt',
#  'training_money-fx_13949.txt',
#  'training_money-fx_13950.txt',
#  'training_money-fx_13958.txt',
#  'training_money-fx_13988.txt',
#  'training_money-fx_13994.txt',
#  'training_money-fx_14034.txt',
#  'training_money-fx_14055.txt',
#  'training_money-fx_14150.txt',
#  'training_money-fx_14178.txt',
#  'training_money-fx_14207.txt',
#  'training_money-fx_1421.txt',
#  'training_money-fx_1457.txt',
#  'training_money-fx_14655.txt',
#  'training_money-fx_14686.txt',
#  'training_money-fx_14757.txt',
#  'training_money-fx_14767.txt',
#  'training_money-fx_14770.txt',
#  'training_money-fx_14777.txt',
#  'training_money-fx_14779.txt',
#  'training_money-fx_14785.txt',
#  'training_money-fx_1503.txt',
#  'training_money-fx_1514.txt',
#  'training_money-fx_1533.txt',
#  'training_money-fx_1553.txt',
#  'training_money-fx_1560.txt',
#  'training_money-fx_1724.txt',
#  'training_money-fx_1811.txt',
#  'training_money-fx_1926.txt',
#  'training_money-fx_1931.txt',
#  'training_money-fx_1943.txt',
#  'training_money-fx_1949.txt',
#  'training_money-fx_1967.txt',
#  'training_money-fx_1976.txt',
#  'training_money-fx_1982.txt',
#  'training_money-fx_1983.txt',
#  'training_money-fx_2022.txt',
#  'training_money-fx_2025.txt',
#  'training_money-fx_2178.txt',
#  'training_money-fx_2181.txt',
#  'training_money-fx_2190.txt',
#  'training_money-fx_221.txt',
#  'training_money-fx_2286.txt',
#  'training_money-fx_2327.txt',
#  'training_money-fx_2352.txt',
#  'training_money-fx_2354.txt',
#  'training_money-fx_2406.txt',
#  'training_money-fx_2452.txt',
#  'training_money-fx_247.txt',
#  'training_money-fx_256.txt',
#  'training_money-fx_2565.txt',
#  'training_money-fx_2576.txt',
#  'training_money-fx_2601.txt',
#  'training_money-fx_2623.txt',
#  'training_money-fx_2626.txt',
#  'training_money-fx_2633.txt',
#  'training_money-fx_2678.txt',
#  'training_money-fx_2683.txt',
#  'training_money-fx_2697.txt',
#  'training_money-fx_2765.txt',
#  'training_money-fx_296.txt',
#  'training_money-fx_2966.txt',
#  'training_money-fx_2993.txt',
#  'training_money-fx_2996.txt',
#  'training_money-fx_3001.txt',
#  'training_money-fx_3002.txt',
#  'training_money-fx_3020.txt',
#  'training_money-fx_3031.txt',
#  'training_money-fx_3044.txt',
#  'training_money-fx_3060.txt',
#  'training_money-fx_3065.txt',
#  'training_money-fx_3067.txt',
#  'training_money-fx_3068.txt',
#  'training_money-fx_307.txt',
#  'training_money-fx_3076.txt',
#  'training_money-fx_3121.txt',
#  'training_money-fx_3137.txt',
#  'training_money-fx_3159.txt',
#  'training_money-fx_3164.txt',
#  'training_money-fx_3222.txt',
#  'training_money-fx_3267.txt',
#  'training_money-fx_3292.txt',
#  'training_money-fx_3338.txt',
#  'training_money-fx_336.txt',
#  'training_money-fx_341.txt',
#  'training_money-fx_3411.txt',
#  'training_money-fx_3419.txt',
#  'training_money-fx_3421.txt',
#  'training_money-fx_3433.txt',
#  'training_money-fx_3435.txt',
#  'training_money-fx_3442.txt',
#  'training_money-fx_3461.txt',
#  'training_money-fx_3482.txt',
#  'training_money-fx_3483.txt',
#  'training_money-fx_3493.txt',
#  'training_money-fx_3514.txt',
#  'training_money-fx_3526.txt',
#  'training_money-fx_3532.txt',
#  'training_money-fx_3533.txt',
#  'training_money-fx_3535.txt',
#  'training_money-fx_3554.txt',
#  'training_money-fx_3584.txt',
#  'training_money-fx_3593.txt',
#  'training_money-fx_3612.txt',
#  'training_money-fx_3666.txt',
#  'training_money-fx_3694.txt',
#  'training_money-fx_3729.txt',
#  'training_money-fx_3735.txt',
#  'training_money-fx_4038.txt',
#  'training_money-fx_4088.txt',
#  'training_money-fx_4090.txt',
#  'training_money-fx_4093.txt',
#  'training_money-fx_411.txt',
#  'training_money-fx_4131.txt',
#  'training_money-fx_4139.txt',
#  'training_money-fx_4170.txt',
#  'training_money-fx_4188.txt',
#  'training_money-fx_4275.txt',
#  'training_money-fx_4293.txt',
#  'training_money-fx_4298.txt',
#  'training_money-fx_4616.txt',
#  'training_money-fx_4633.txt',
#  'training_money-fx_4666.txt',
#  'training_money-fx_4675.txt',
#  'training_money-fx_4680.txt',
#  'training_money-fx_4682.txt',
#  'training_money-fx_4703.txt',
#  'training_money-fx_4709.txt',
#  'training_money-fx_4712.txt',
#  'training_money-fx_4720.txt',
#  'training_money-fx_475.txt',
#  'training_money-fx_4768.txt',
#  'training_money-fx_4783.txt',
#  'training_money-fx_4809.txt',
#  'training_money-fx_4822.txt',
#  'training_money-fx_4829.txt',
#  'training_money-fx_4882.txt',
#  'training_money-fx_5070.txt',
#  'training_money-fx_5176.txt',
#  'training_money-fx_5181.txt',
#  'training_money-fx_5183.txt',
#  'training_money-fx_519.txt',
#  'training_money-fx_5190.txt',
#  'training_money-fx_5193.txt',
#  'training_money-fx_5201.txt',
#  'training_money-fx_5204.txt',
#  'training_money-fx_5206.txt',
#  'training_money-fx_522.txt',
#  'training_money-fx_5223.txt',
#  'training_money-fx_5232.txt',
#  'training_money-fx_5241.txt',
#  'training_money-fx_5269.txt',
#  'training_money-fx_5271.txt',
#  'training_money-fx_5277.txt',
#  'training_money-fx_5279.txt',
#  'training_money-fx_5280.txt',
#  'training_money-fx_5290.txt',
#  'training_money-fx_5336.txt',
#  'training_money-fx_5338.txt',
#  'training_money-fx_5344.txt',
#  'training_money-fx_5360.txt',
#  'training_money-fx_5394.txt',
#  'training_money-fx_5404.txt',
#  'training_money-fx_5412.txt',
#  'training_money-fx_5434.txt',
#  'training_money-fx_5439.txt',
#  'training_money-fx_5778.txt',
#  'training_money-fx_5779.txt',
#  'training_money-fx_5811.txt',
#  'training_money-fx_5814.txt',
#  'training_money-fx_5819.txt',
#  'training_money-fx_5841.txt',
#  'training_money-fx_5858.txt',
#  'training_money-fx_5861.txt',
#  'training_money-fx_5905.txt',
#  'training_money-fx_5909.txt',
#  'training_money-fx_5945.txt',
#  'training_money-fx_5998.txt',
#  'training_money-fx_6044.txt',
#  'training_money-fx_6046.txt',
#  'training_money-fx_6083.txt',
#  'training_money-fx_6108.txt',
#  'training_money-fx_6137.txt',
#  'training_money-fx_6338.txt',
#  'training_money-fx_6357.txt',
#  'training_money-fx_6359.txt',
#  'training_money-fx_6394.txt',
#  'training_money-fx_6399.txt',
#  'training_money-fx_6400.txt',
#  'training_money-fx_6426.txt',
#  'training_money-fx_6445.txt',
#  'training_money-fx_6452.txt',
#  'training_money-fx_6531.txt',
#  'training_money-fx_6543.txt',
#  'training_money-fx_6576.txt',
#  'training_money-fx_6945.txt',
#  'training_money-fx_6981.txt',
#  'training_money-fx_7020.txt',
#  'training_money-fx_7027.txt',
#  'training_money-fx_7036.txt',
#  'training_money-fx_7043.txt',
#  'training_money-fx_7080.txt',
#  'training_money-fx_7100.txt',
#  'training_money-fx_7159.txt',
#  'training_money-fx_7204.txt',
#  'training_money-fx_7207.txt',
#  'training_money-fx_7312.txt',
#  'training_money-fx_7313.txt',
#  'training_money-fx_7375.txt',
#  'training_money-fx_7394.txt',
#  'training_money-fx_7429.txt',
#  'training_money-fx_7460.txt',
#  'training_money-fx_7538.txt',
#  'training_money-fx_7559.txt',
#  'training_money-fx_7562.txt',
#  'training_money-fx_7568.txt',
#  'training_money-fx_7571.txt',
#  'training_money-fx_7587.txt',
#  'training_money-fx_7599.txt',
#  'training_money-fx_7614.txt',
#  'training_money-fx_7628.txt',
#  'training_money-fx_7652.txt',
#  'training_money-fx_7669.txt',
#  'training_money-fx_7710.txt',
#  'training_money-fx_7716.txt',
#  'training_money-fx_7764.txt',
#  'training_money-fx_7769.txt',
#  'training_money-fx_7804.txt',
#  'training_money-fx_7950.txt',
#  'training_money-fx_8064.txt',
#  'training_money-fx_8074.txt',
#  'training_money-fx_8097.txt',
#  'training_money-fx_8098.txt',
#  'training_money-fx_8145.txt',
#  'training_money-fx_8147.txt',
#  'training_money-fx_8153.txt',
#  'training_money-fx_8168.txt',
#  'training_money-fx_8182.txt',
#  'training_money-fx_8189.txt',
#  'training_money-fx_8194.txt',
#  'training_money-fx_8199.txt',
#  'training_money-fx_8234.txt',
#  'training_money-fx_8247.txt',
#  'training_money-fx_8299.txt',
#  'training_money-fx_8302.txt',
#  'training_money-fx_8309.txt',
#  'training_money-fx_8563.txt',
#  'training_money-fx_8578.txt',
#  'training_money-fx_8584.txt',
#  'training_money-fx_8586.txt',
#  'training_money-fx_8587.txt',
#  'training_money-fx_8588.txt',
#  'training_money-fx_8590.txt',
#  'training_money-fx_8591.txt',
#  'training_money-fx_8597.txt',
#  'training_money-fx_8605.txt',
#  'training_money-fx_8607.txt',
#  'training_money-fx_8621.txt',
#  'training_money-fx_8629.txt',
#  'training_money-fx_8641.txt',
#  'training_money-fx_8657.txt',
#  'training_money-fx_8658.txt',
#  'training_money-fx_8664.txt',
#  'training_money-fx_8670.txt',
#  'training_money-fx_8674.txt',
#  'training_money-fx_8678.txt',
#  'training_money-fx_8710.txt',
#  'training_money-fx_8714.txt',
#  'training_money-fx_872.txt',
#  'training_money-fx_8723.txt',
#  'training_money-fx_8728.txt',
#  'training_money-fx_8735.txt',
#  'training_money-fx_8760.txt',
#  'training_money-fx_8796.txt',
#  'training_money-fx_8845.txt',
#  'training_money-fx_8884.txt',
#  'training_money-fx_8922.txt',
#  'training_money-fx_8984.txt',
#  'training_money-fx_9007.txt',
#  'training_money-fx_9022.txt',
#  'training_money-fx_903.txt',
#  'training_money-fx_9054.txt',
#  'training_money-fx_9055.txt',
#  'training_money-fx_9061.txt',
#  'training_money-fx_9079.txt',
#  'training_money-fx_9118.txt',
#  'training_money-fx_9120.txt',
#  'training_money-fx_9128.txt',
#  'training_money-fx_9129.txt',
#  'training_money-fx_913.txt',
#  'training_money-fx_9131.txt',
#  'training_money-fx_9132.txt',
#  'training_money-fx_9134.txt',
#  'training_money-fx_9138.txt',
#  'training_money-fx_9149.txt',
#  'training_money-fx_915.txt',
#  'training_money-fx_9162.txt',
#  'training_money-fx_9164.txt',
#  'training_money-fx_9166.txt',
#  'training_money-fx_9170.txt',
#  'training_money-fx_9213.txt',
#  'training_money-fx_9214.txt',
#  'training_money-fx_9216.txt',
#  'training_money-fx_9217.txt',
#  'training_money-fx_9218.txt',
#  'training_money-fx_9220.txt',
#  'training_money-fx_9222.txt',
#  'training_money-fx_9224.txt',
#  'training_money-fx_926.txt',
#  'training_money-fx_9261.txt',
#  'training_money-fx_9282.txt',
#  'training_money-fx_9295.txt',
#  'training_money-fx_9299.txt',
#  'training_money-fx_9361.txt',
#  'training_money-fx_9377.txt',
#  'training_money-fx_942.txt',
#  'training_money-fx_943.txt',
#  'training_money-fx_9498.txt',
#  'training_money-fx_953.txt',
#  'training_money-fx_9534.txt',
#  'training_money-fx_9535.txt',
#  'training_money-fx_9656.txt',
#  'training_money-fx_9681.txt',
#  'training_money-fx_9686.txt',
#  'training_money-fx_9689.txt',
#  'training_money-fx_9698.txt',
#  'training_money-fx_9699.txt',
#  'training_money-fx_9701.txt',
#  'training_money-fx_9720.txt',
#  'training_money-fx_9727.txt',
#  'training_money-fx_9730.txt',
#  'training_money-fx_9745.txt',
#  'training_money-fx_9753.txt',
#  'training_money-fx_9764.txt',
#  'training_money-fx_9781.txt',
#  'training_money-fx_9783.txt',
#  'training_money-fx_9784.txt',
#  'training_money-fx_9792.txt',
#  'training_money-fx_9797.txt',
#  'training_money-fx_9848.txt',
#  'training_money-fx_9851.txt',
#  'training_money-fx_9852.txt',
#  'training_money-fx_9855.txt',
#  'training_money-fx_9857.txt',
#  'training_money-fx_9862.txt',
#  'training_money-fx_9864.txt',
#  'training_money-fx_9871.txt',
#  'training_money-fx_9880.txt',
#  'training_money-fx_9923.txt',
#  'training_money-fx_9946.txt',
#  'training_money-fx_9955.txt',
#  'training_money-fx_9957.txt',
#  'training_money-fx_9975.txt',
#  'training_money-fx_999.txt',
#  '__MACOSX']

# %%
target=[]
article_text=[]
for file in files:
    if '.txt' not in file:continue
    f=open(path+file,encoding='latin-1')
    article_text.append(" ".join([line.strip() for line in
                                       f if line.strip()!=""]))
    if "crude" in file:
        target.append("crude")
    else:
        target.append("money")
    f.close()

# %%
files[:2]
# Out:
# ['training_crude_10011.txt', 'training_crude_10078.txt']

# %%
mydata=pd.DataFrame({'target':target,'article_text':article_text})

# %%
mydata.head()
# Out:
#   target                                       article_text
# 0  crude  CANADA OIL EXPORTS RISE 20 PCT IN 1986 Canadia...
# 1  crude  BP &lt;BP> DOES NOT PLAN TO HIKE STANDARD &lt;...
# 2  crude  BP&lt;BP> OFFER RAISES EXPECTATIONS FOR OIL VA...
# 3  crude  USX &lt;X> SAYS TALKS ENDED WITH BRITISH PETRO...
# 4  crude  BP &lt;BP> MAY HAVE TO RAISE BID -  ANALYSTS B...

# %%
mydata.shape
# Out:
# (927, 2)

# %% [markdown]
# # Text Data Exploration with word cloud

# %%
# conda install -c https://conda.anaconda.org/conda-forge wordcloud
from wordcloud import WordCloud

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
all_articles=' '.join(mydata['article_text'])

# %%
mydata.head(2)
# Out:
#   target                                       article_text
# 0  crude  CANADA OIL EXPORTS RISE 20 PCT IN 1986 Canadia...
# 1  crude  BP &lt;BP> DOES NOT PLAN TO HIKE STANDARD &lt;...

# %%
all_articles
# Out:
# 'CANADA OIL EXPORTS RISE 20 PCT IN 1986 Canadian oil exports rose 20 pct in 1986 over the previous year to 33.96 mln cubic meters, while oil imports soared 25.2 pct to 20.58 mln cubic meters, Statistics Canada said. Production, meanwhile, was unchanged from the previous year at 91.09 mln cubic feet. Natural gas exports plunged 19.4 pct to 21.09 billion cubic meters, while Canadian sales slipped 4.1 pct to 48.09 billion cubic meters. The federal agency said that in December oil production fell 4.0 pct to 7.73 mln cubic meters, while exports rose 5.2 pct to 2.84 mln cubic meters and imports rose 12.3 pct to 2.1 mln cubic meters. Natural gas exports fell 16.3 pct in the month 2.51 billion cubic meters and Canadian sales eased 10.2 pct to 5.25 billion cubic meters. BP &lt;BP> DOES NOT PLAN TO HIKE STANDARD &lt;SRD> BID British Petroleum Co Plc does not intend to raise the price of its planned 70 dlr per share offer for the publicly held 45 pct of Standard Oil Co, BP Managing Director David Simon said. "We don\'t seen this as any progressive bidding game," he told reporters at a news conference. BP now owns 55 pct of Standard\'s stock. Simon said BP had carefully considered the amount of its planned bid and he quoted an oil analyst, whom he would not identify, as saying BP\'s careful evaluation means the company is not going to raise its offer. "I think that (an increase) would be totally wrong. I think the price is very fair and it is much to early to speculate about ligigation," he said. "Let\'s wait and see how the offer runs." Another official declined to speculate under what circumstances BP might raise its bid. The BP official said the 70 dlrs a share offer is 7.2 times Standard\'s 1986 cash flow and 56 pct above an independent evaluation of the company\'s assets, including the value of its oil, natural gas liquids and natural gas reserves. He said the price Royal Dutch/Shell Group &lt;RD> &lt;SC> paid for publicly held Shell Oil Co shares in 1985 was 5.1 times cash flow. The BP official also said the 70 dlr bid is a 40 pct premium over Standard\'s stock price over the past year. BP Group Treasurer Rodney Chase said more than half to as much as two-third\'s of the 7.4 billion dlrs BP needs for its offer will come from existing sources. The rest will be financed by new debt. BP will draw in cash from its operating companies around the world and is also arranging a five billion dlr line of credit, he explained. The company\'s debt to equity ratio will rise 11 or 12 percentage points from the current 33 pct if the offer is completed, Chase said. But the ratio will be back below 40 pct within 12 months, he added. Chase also said 50 to 60 pct of Standard Oil\'s publicly held shares are held by financial institutions. Simon said Standard\'s board was informed of the offer on March nine and has been considering it since that time. He said BP does not expect any regulatory problems that would delay completion of the acquisition. "We have informed Washington of our intentions and we\'ve already been an integral part of ownership of U.S. oil reserves," he pointed out. Simon said there is a good chance that current world oil prices of about 18 dlrs a barrel could be maintained, and that the more stable market is due mostly to changes in policy in Saudi Arabia and other OPEC members to control oil production. "We think there are signals that current conditions are more favorable than they have been for sometime," Simon said. "We have hopes for greater stability, but we do not see prices going much higher," he added. BP&lt;BP> OFFER RAISES EXPECTATIONS FOR OIL VALUES British Petroleum Plc\'s plan to pay 7.4 billion dlrs for less than half of Standard Oil Co has signalled higher values in the U.S. oil patch, analysts said. "I think that BP\'s bid is a very strong affirmation and clear signal that they have confidence in the U.S., and they think the barrel of oil in the ground is going to go higher," said Sanford Margoshes of Shearson Lehma ...

# %%
crude_articles=" ".join(mydata.loc[mydata['target']=='crude','article_text'])

# %%
money_articles=" ".join(mydata.loc[mydata['target']=='money','article_text'])

# %%
wordcloud = WordCloud().generate(all_articles)
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off");

# %%
wordcloud.words_
# Out:
# {'April': 0.04925290536801328,
#  'Bank England': 0.0774764803541782,
#  'Bank Japan': 0.07194244604316546,
#  'Brazil': 0.0387382401770891,
#  'Bundesbank': 0.06087437742114001,
#  'Ecuador': 0.06917542888765911,
#  'Energy': 0.04095185390149419,
#  'England said': 0.055893746541228556,
#  'February': 0.09629219701162148,
#  'Federal Reserve': 0.04261206419479801,
#  'Finance Minister': 0.0387382401770891,
#  'Gulf': 0.03763143331488655,
#  'January': 0.07194244604316546,
#  'Japan': 0.06806862202545656,
#  'Japanese': 0.08301051466519092,
#  'March': 0.0896513558384062,
#  'OPEC': 0.11510791366906475,
#  'President': 0.03763143331488655,
#  'SAY': 0.06972883231876037,
#  'Saudi Arabia': 0.059767570558937465,
#  'United State': 0.059767570558937465,
#  'West Germany': 0.06806862202545656,
#  'accord': 0.03818483674598783,
#  'action': 0.040398450470392915,
#  'added': 0.10348644161593802,
#  'agreed': 0.04316546762589928,
#  'agreement': 0.0448256779192031,
#  'already': 0.036524626452684006,
#  'analyst': 0.04537908135030437,
#  'analysts said': 0.058107360265633644,
#  'another': 0.036524626452684006,
#  'asked': 0.03763143331488655,
#  'average': 0.0448256779192031,
#  'back': 0.04095185390149419,
#  'bank': 0.17266187050359713,
#  'banker': 0.03541781959048146,
#  'barrels per': 0.04261206419479801,
#  'billion dlr': 0.1571665744327615,
#  'billion stg': 0.042058660763696736,
#  'called': 0.034864416159380185,
#  'central bank': 0.1853901494189264,
#  'change': 0.07028223574986164,
#  'close': 0.04261206419479801,
#  'come': 0.036524626452684006,
#  'companies': 0.04316546762589928,
#  'company': 0.0509131156613171,
#  'compared': 0.03597122302158273,
#  'continue': 0.036524626452684006,
#  'contract': 0.04427227448810182,
#  'cost': 0.04648588821250692,
#  'countries': 0.06032097399003874,
#  'country': 0.05644714997232983,
#  'crude oil': 0.12119535141117875,
#  'currencies': 0.04980630879911455,
#  'currency': 0.12728278915329275,
#  'current': 0.043718871057000556,
#  'cut': 0.07360265633646929,
#  'day': 0.03763143331488655,
#  'dealers said': 0.11455451023796348,
#  'debt': 0.04703929164360819,
#  'decline': 0.05201992252351965,
#  'demand': 0.061427780852241286,
#  'development': 0.048699501936912006,
#  'dlrs barrel': 0.0653016048699502,
#  'dollar': 0.2872163807415606,
#  'drilling': 0.03763143331488655,
#  'drop': 0.04316546762589928,
#  'due': 0.058107360265633644,
#  'earlier': 0.04703929164360819,
#  'economic': 0.0630879911455451,
#  'economy': 0.06419479800774765,
#  'end': 0.06640841173215274,
#  'estimated': 0.03707802988378528,
#  'exchange rate': 0.14554510237963475,
#  'expect': 0.03597122302158273,
#  'expected': 0.10459324847814057,
#  'export': 0.08411732152739347,
#  'fall': 0.059767570558937465,
#  'field': 0.03707802988378528,
#  'financial': 0.03818483674598783,
#  'firm': 0.04814609850581074,
#  'first': 0.050359712230215826,
#  'foreign': 0.061427780852241286,
#  'foreign exchange': 0.10127282789153293,
#  'future': 0.05257332595462092,
#  'good': 0.04095185390149419,
#  'government': 0.14111787493082456,
#  'growth': 0.06474820143884892,
#  'high': 0.04814609850581074,
#  'higher': 0.06087437742114001,
#  'hold': 0.036524626452684006,
#  'import': 0.0570005534034311,
#  'including': 0.036524626452684006,
#  'increase': 0.06972883231876037,
#  'industry': 0.05257332595462092,
#  'inflation': 0.04150525733259546,
#  'interest': 0.04648588821250692,
#  'interest rate': 0.08743774211400111,
#  'international': 0.06364139457664637,
#  'intervention': 0.042058660763696736,
#  'investment': 0.04814609850581074,
#  'issue': 0.04814609850581074,
#  'last month': 0.05755395683453238,
#  'last week': 0.04095185390149419,
#  'last year': 0.0957387935805202,
#  'less': 0.0387382401770891,
#  'level': 0.10625345877144439,
#  'likely': 0.0509131156613171,
#  'loan': 0.04980630879911455,
#  'long': 0.03597122302158273,
#  'lower': 0.06032097399003874,
#  'made': 0.05478693967902601,
#  'major': 0.04095185390149419,
#  'make': 0.05201992252351965,
#  'many': 0.03984504703929164,
#  'mark': 0.07138904261206419,
#  'market': 0.13779745434421695,
#  'may': 0.08743774211400111,
#  'measure': 0.051466519092418374,
#  'meeting': 0.06917542888765911,
#  'member': 0.03763143331488655,
#  'might': 0.03818483674598783,
#  'mln barrel': 0.1018262313226342,
#  'mln bpd': 0.09629219701162148,
#  'mln dlr': 0.12562257885998893,
#  'mln stg': 0.23242944106253458,
#  'money market': 0.17044825677919204,
#  'month': 0.05921416712783619,
#  'move': 0.055893746541228556,
#  'much': 0.05534034311012728,
#  'natural gas': 0.043718871057000556,
#  'need': 0.06364139457664637,
#  'new': 0.15329275041505258,
#  'noted': 0.03597122302158273,
#  'now': 0.09407858328721638,
#  'official': 0.07304925290536801,
#  'official said': 0.036524626452684006,
#  'officials said': 0.04316546762589928,
#  'oil': 0.10514665190924184,
#  'oil gas': 0.05201992252351965,
#  'oil price': 0.1079136690647482,
#  'one': 0.11566131710016603,
#  'operation': 0.04316546762589928,
#  'output': 0.04095185390149419,
#  'part': 0.042058660763696736,
#  'pct': 0.22910902047592696,
#  'pct mln': 0.04648588821250692,
#  'per day': 0.050359712230215826,
#  'period': 0.03707802988378528,
#  'plan': 0.06032097399003874,
#  'point': 0.034864416159380185,
#  'policy': 0.06862202545655784,
#  'pressure': 0.0387382401770891,
#  'price': 0.17487548422800223,
#  'problem': 0.04316546762589928,
#  'production': 0.08909795240730492,
#  'proposal': 0.042058660763696736,
#  'raise': 0.03541781959048146,
#  'rate': 0.10514665190924184,
#  'recent': 0.06032097399003874,
#  'refinery': 0.0509131156613171,
#  'remain': 0.04150525733259546,
#  'report': 0.0752628666297731,
#  'result': 0.03984504703929164,
#  'rise': 0.07138904261206419,
#  'said': 1.0,
#  'sale': 0.05866076369673492,
#  'see': 0.0570005534034311,
#  'seen': 0.03541781959048146,
#  'set': 0.07360265633646929,
#  'share': 0.040398450470392915,
#  'sources said': 0.06640841173215274,
#  'spokesman said': 0.03541781959048146,
#  'state': 0.051466519092418374,
#  'sterling': 0.05755395683453238,
#  'stg band': 0.036524626452684006,
#  'still': 0.06032097399003874,
#  'stock': 0.03597122302158273,
#  'support': 0.040398450470392915,
#  'system': 0.04427227448810182,
#  'take': 0.03707802988378528,
#  'talk': 0.04261206419479801,
#  'target': 0.048699501936912006,
#  'tax': 0.05478693967902601,
#  'time': 0.08024349750968456,
#  'today': 0.11898173768677366,
#  'total': 0.0509131156613171,
#  'trade': 0.08522412838959602,
#  'trade deficit': 0.034864416159380185,
#  'trading': 0.048699501936912006,
#  'value': 0.03541781959048146,
#  'want': 0.034864416159380185,
#  'way': 0.04261206419479801,
#  'week': 0.07470946319867183,
#  'well': 0.07636967349197565,
#  'will': 0.3281682346430548,
#  'world': 0.042058660763696736,
#  'year': 0.13392363032650803,
#  'yen': 0.10459324847814057,
#  'yesterday': 0.06862202545655784}

# %%
wordcloud = WordCloud().generate(crude_articles)
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
# Out:
# (-0.5, 399.5, 199.5, -0.5)

# %%
wordcloud = WordCloud().generate(money_articles)
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
# Out:
# (-0.5, 399.5, 199.5, -0.5)

# %% [markdown]
# # Text Data Exploration with nltk

# %%
from nltk import word_tokenize

# %%
# nltk.download()
# Out:
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml
# True

# %%
tokens=word_tokenize(money_articles)

# %%
tokens[:10]
# Out:
# ['BRITISH',
#  ',',
#  'FRENCH',
#  'MINISTERS',
#  'DISCUSS',
#  'PUBLIC',
#  'SPENDING',
#  'French',
#  'Finance',
#  'Minister']

# %%
len(tokens)
# Out:
# 109212

# %%
money_articles_Text=nltk.Text(tokens)

# %%
money_articles_Text
# Out:
# <Text: BRITISH , FRENCH MINISTERS DISCUSS PUBLIC SPENDING French...>

# %%
money_articles_Text.concordance('dlr')
# Out:
# Displaying 25 of 60 matches:
# oil prices dropped from around the 30 dlr level . The index , base 1975 , close
# JAPAN SETS ASIDE YEN FUNDS TO PREVENT DLR FALL The 50-day provisional 1987/88 b
# JAPAN SETS ASIDE YEN FUNDS TO PREVENT DLR FALL The 50-day provisional 1987/88 b
# erate with other nations to stabilize dlr , Sumita Japan will continue to coope
# erate with other nations to stabilize dlr , Sumita SUMITA SAYS HE DOES NOT EXPE
# ry economic restructuring , he said . DLR FALLS ON FEAR TOKYO WO N'T HIKE DEMAN
#  nations committed in Paris to stable dlr above 150 yen Nakasone says major nat
#  nations committed in Paris to stable dlr above 150 yen Miyazawa says major nat
# ns have intervened aggressively since dlr fell below 150 yen Miyazawa says majo
# ns have intervened aggressively since dlr fell below 150 yen G-6 WANTS TO HOLD
#  fell below 150 yen G-6 WANTS TO HOLD DLR ABOVE 150 YEN - NAKASONE Prime Minist
#  cutting the country 's 169.8 billion dlr trade deficit , they said . BAHRAIN I
# a year ago . REUTER G-6 WANTS TO HOLD DLR ABOVE 150 YEN - NAKASONE Prime Minist
# ry economic restructuring , he said . DLR FALLS ON FEARS , MIYAZAWA SAYS Financ
# id . U.S. APPEARS TO TOLERATE FURTHER DLR DECLINE In a bid to hasten Japan 's p
# progress in cutting the 169.8 billion dlr trade deficit , is learning now that
# that Japan earned a record 18 billion dlr trade surplus in the first two months
#  cutting the country 's 169.8 billion dlr trade deficit , they said . JAPAN CON
#  Co Ltd > said . FED SETS TWO BILLION DLR CUSTOMER REPURCHASE , FED SAYS FED SE
# CHASE , FED SAYS FED SETS TWO BILLION DLR CUSTOMER REPURCHASE , FED SAYS FED AD
# ilders . BRAZIL TEMPORARILY LEGALISES DLR PARALLEL MARKET Brazilian President J
# eiredo . SARNEY TEMPORARILY LEGALISES DLR PARALLEL MARKET Brazilian President J
# e bank has established a five billion dlr swap limit with the U.S. Federal Rese
# APAN MINISTRY ASKS TRUST BANKS TO CUT DLR SALES The Finance Ministry has asked
# uses . VOLCKER WARNS AGAINST SIZEABLE DLR DECLINE Federal Reserve Board Chairma

# %%
money_articles_Text.similar('dlr')
# Out:
# dollar yen to pct billion trade their and whether february currencies
# current appropriate mln stg japan meet cooperate float which

# %%
money_articles_Text.common_contexts(['dollar','dlr'])
# Out:
# says_level cut_sales further_decline hold_above the_nikkeiren

# %% [markdown]
# # Text Data features with tfidf

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
from nltk.stem.wordnet import WordNetLemmatizer
from nltk.corpus import stopwords
from string import punctuation
from nltk.tokenize import word_tokenize

# %%
# nltk.download('stopwords')
# nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\wordnet.zip.
# True

# %%
stopwords.words('english')

# For additional stopwords see the below link
# https://gist.github.com/sebleier/554280
# Out:
# ['i',
#  'me',
#  'my',
#  'myself',
#  'we',
#  'our',
#  'ours',
#  'ourselves',
#  'you',
#  "you're",
#  "you've",
#  "you'll",
#  "you'd",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'he',
#  'him',
#  'his',
#  'himself',
#  'she',
#  "she's",
#  'her',
#  'hers',
#  'herself',
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'they',
#  'them',
#  'their',
#  'theirs',
#  'themselves',
#  'what',
#  'which',
#  'who',
#  'whom',
#  'this',
#  'that',
#  "that'll",
#  'these',
#  'those',
#  'am',
#  'is',
#  'are',
#  'was',
#  'were',
#  'be',
#  'been',
#  'being',
#  'have',
#  'has',
#  'had',
#  'having',
#  'do',
#  'does',
#  'did',
#  'doing',
#  'a',
#  'an',
#  'the',
#  'and',
#  'but',
#  'if',
#  'or',
#  'because',
#  'as',
#  'until',
#  'while',
#  'of',
#  'at',
#  'by',
#  'for',
#  'with',
#  'about',
#  'against',
#  'between',
#  'into',
#  'through',
#  'during',
#  'before',
#  'after',
#  'above',
#  'below',
#  'to',
#  'from',
#  'up',
#  'down',
#  'in',
#  'out',
#  'on',
#  'off',
#  'over',
#  'under',
#  'again',
#  'further',
#  'then',
#  'once',
#  'here',
#  'there',
#  'when',
#  'where',
#  'why',
#  'how',
#  'all',
#  'any',
#  'both',
#  'each',
#  'few',
#  'more',
#  'most',
#  'other',
#  'some',
#  'such',
#  'no',
#  'nor',
#  'not',
#  'only',
#  'own',
#  'same',
#  'so',
#  'than',
#  'too',
#  'very',
#  's',
#  't',
#  'can',
#  'will',
#  'just',
#  'don',
#  "don't",
#  'should',
#  "should've",
#  'now',
#  'd',
#  'll',
#  'm',
#  'o',
#  're',
#  've',
#  'y',
#  'ain',
#  'aren',
#  "aren't",
#  'couldn',
#  "couldn't",
#  'didn',
#  "didn't",
#  'doesn',
#  "doesn't",
#  'hadn',
#  "hadn't",
#  'hasn',
#  "hasn't",
#  'haven',
#  "haven't",
#  'isn',
#  "isn't",
#  'ma',
#  'mightn',
#  "mightn't",
#  'mustn',
#  "mustn't",
#  'needn',
#  "needn't",
#  'shan',
#  "shan't",
#  'shouldn',
#  "shouldn't",
#  'wasn',
#  "wasn't",
#  'weren',
#  "weren't",
#  'won',
#  "won't",
#  'wouldn',
#  "wouldn't"]

# %%
list(punctuation)
# Out:
# ['!',
#  '"',
#  '#',
#  '$',
#  '%',
#  '&',
#  "'",
#  '(',
#  ')',
#  '*',
#  '+',
#  ',',
#  '-',
#  '.',
#  '/',
#  ':',
#  ';',
#  '<',
#  '=',
#  '>',
#  '?',
#  '@',
#  '[',
#  '\\',
#  ']',
#  '^',
#  '_',
#  '`',
#  '{',
#  '|',
#  '}',
#  '~']

# %%
lemma = WordNetLemmatizer()
my_stop=set(stopwords.words('english')+list(punctuation))

# %%
my_stop
# Out:
# {'!',
#  '"',
#  '#',
#  '$',
#  '%',
#  '&',
#  "'",
#  '(',
#  ')',
#  '*',
#  '+',
#  ',',
#  '-',
#  '.',
#  '/',
#  ':',
#  ';',
#  '<',
#  '=',
#  '>',
#  '?',
#  '@',
#  '[',
#  '\\',
#  ']',
#  '^',
#  '_',
#  '`',
#  'a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'ain',
#  'all',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  'aren',
#  "aren't",
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  'couldn',
#  "couldn't",
#  'd',
#  'did',
#  'didn',
#  "didn't",
#  'do',
#  'does',
#  'doesn',
#  "doesn't",
#  'doing',
#  'don',
#  "don't",
#  'down',
#  'during',
#  'each',
#  'few',
#  'for',
#  'from',
#  'further',
#  'had',
#  'hadn',
#  "hadn't",
#  'has',
#  'hasn',
#  "hasn't",
#  'have',
#  'haven',
#  "haven't",
#  'having',
#  'he',
#  'her',
#  'here',
#  'hers',
#  'herself',
#  'him',
#  'himself',
#  'his',
#  'how',
#  'i',
#  'if',
#  'in',
#  'into',
#  'is',
#  'isn',
#  "isn't",
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'just',
#  'll',
#  'm',
#  'ma',
#  'me',
#  'mightn',
#  "mightn't",
#  'more',
#  'most',
#  'mustn',
#  "mustn't",
#  'my',
#  'myself',
#  'needn',
#  "needn't",
#  'no',
#  'nor',
#  'not',
#  'now',
#  'o',
#  'of',
#  'off',
#  'on',
#  'once',
#  'only',
#  'or',
#  'other',
#  'our',
#  'ours',
#  'ourselves',
#  'out',
#  'over',
#  'own',
#  're',
#  's',
#  'same',
#  'shan',
#  "shan't",
#  'she',
#  "she's",
#  'should',
#  "should've",
#  'shouldn',
#  "shouldn't",
#  'so',
#  'some',
#  'such',
#  't',
#  'than',
#  'that',
#  "that'll",
#  'the',
#  'their',
#  'theirs',
#  'them',
#  'themselves',
#  'then',
#  'there',
#  'these',
#  'they',
#  'this',
#  'those',
#  'through',
#  'to',
#  'too',
#  'under',
#  'until',
#  'up',
#  've',
#  'very',
#  'was',
#  'wasn',
#  "wasn't",
#  'we',
#  'were',
#  'weren',
#  "weren't",
#  'what',
#  'when',
#  'where',
#  'which',
#  'while',
#  'who',
#  'whom',
#  'why',
#  'will',
#  'with',
#  'won',
#  "won't",
#  'wouldn',
#  "wouldn't",
#  'y',
#  'you',
#  "you'd",
#  "you'll",
#  "you're",
#  "you've",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  '{',
#  '|',
#  '}',
#  '~'}

# %%
# Lemmatization example

wd = ['running', 'runs', 'ran']
[lemma.lemmatize(word, pos='v') for word in wd]
# Out:
# ['run', 'run', 'run']

# %%
def split_into_lemmas(message):
    message=message.lower()
    words = word_tokenize(message)
    words_sans_stop=[]
    for word in words :
        if word in my_stop:continue
        words_sans_stop.append(word)
    return [lemma.lemmatize(word, pos='v') for word in words_sans_stop]

# %%
tfidf= TfidfVectorizer(analyzer=split_into_lemmas,min_df=20,max_df=500,
                       stop_words=my_stop)

# %%
tfidf.fit(mydata['article_text'])
# Out:
# TfidfVectorizer(analyzer=<function split_into_lemmas at 0x10B65F60>,
#         binary=False, decode_error='strict', dtype=<class 'numpy.int64'>,
#         encoding='utf-8', input='content', lowercase=True, max_df=500,
#         max_features=None, min_df=20, ngram_range=(1, 1), norm='l2',
#         preprocessor=None, smooth_idf=True,
#         stop_words={'that', 'each', 'yourself', '-', 'i', 'while', 'no', 'didn', "weren't", ']', 'against', 'it', 'isn', 'any', 'doesn', ')', 'when', 'is', 'mightn', 'now', 'was', 'only', ':', 'being', 'doing', 'you', '\\', 'themselves', 'been', "couldn't", 'so', 'below', 'yours', "mustn't", 're', 'hers', '...'will', 'haven', 'has', 'he', '`', 'than', "hasn't", 'himself', "'", "you'll", 'm', 'needn', 'both'},
#         strip_accents=None, sublinear_tf=False,
#         token_pattern='(?u)\\b\\w\\w+\\b', tokenizer=None, use_idf=True,
#         vocabulary=None)

# %%
tfidf_data=tfidf.transform(mydata['article_text'])

# %%
tfidf_data.shape
# Out:
# (927, 795)

# %%
tfidf_data
# Out:
# <927x795 sparse matrix of type '<class 'numpy.float64'>'
# 	with 46952 stored elements in Compressed Sparse Row format>

# %%
# tfidf_data.get_feature_names()
# tfidf_data.idf_
tfidf_df = pd.DataFrame(tfidf_data.toarray(), columns = tfidf.get_feature_names())
tfidf_df
# Out:
#            ''        --       ...         1       1.5        10  100  \
# 0    0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.0
# 1    0.142773  0.000000  0.000000  0.000000  0.000000  0.000000  0.0
# 2    0.119770  0.000000  0.035324  0.000000  0.000000  0.000000  0.0
# 3    0.221078  0.000000  0.000000  0.000000  0.000000  0.000000  0.0
# 4    0.049495  0.000000  0.000000  0.000000  0.000000  0.000000  0.0
# 5    0.000000  0.089909  0.000000  0.000000  0.000000  0.000000  0.0
# 6    0.076925  0.000000  0.000000  0.000000  0.000000  0.000000  0.0
# 7    0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.0
# 8    0.159095  0.050199  0.000000  0.000000  0.000000  0.000000  0.0
# 9    0.121228  0.000000  0.166850  0.000000  0.000000  0.065753  0.0
# 10   0.129668  0.035069  0.000000  0.000000  0.000000  0.030142  0.0
# 11   0.236290  0.000000  0.000000  0.135112  0.000000  0.000000  0.0
# 12   0.042533  0.080523  0.000000  0.000000  0.000000  0.000000  0.0
# 13   0.061905  0.000000  0.000000  0.141591  0.000000  0.000000  0.0
# 14   0.243070  0.000000  0.000000  0.000000  0.000000  0.000000  0.0
# 15   0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.0
# 16   0.203271  0.000000  0.000000  0.000000  0.000000  0.000000  0.0
# 17   0.075642  0.000000  0.000000  0.000000  0.000000  0.000000  0.0
# 18   0.146931  0.000000  0.000000  0.000000  0.000000  0.000000  0.0
# 19   0.285547  0.000000  0.000000  0.108852  0.000000  0.000000  0.0
# 20   0.037912  0.000000  0.000000  0.000000  0.000000  0.000000  0.0
# 21   0.181271  0.228784  0.000000  0.138203  0.000000  0.000000  0.0
# 22   0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.0
# 23   0.038438  0.000000  0.000000  0.000000  0.000000  0.000000  0.0
# 24   0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.0
# 25   0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.0
# 26   0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.0
# 27   0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.0
# 28   0.000000  0.000000  0.973157  0.000000  0.000000  0.012784  0.0
# 29   0.082722  0.000000  0.000000  0.000000  0.000000  0.000000  0.0
# ..        ...       ...       ...       ...       ...       ...  ...
# 897  0.199810  0.000000  0.000000  0.000000  0.000000  0.000000  0.0
# 898  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.0
# 899  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.0
# 900  0.000000  0.000000  0.000000  0.082848  0.000000  0.000000  0.0
# 901  0.039955  0.151282  0.000000  0.000000  0.000000  0.000000  0.0
# 902  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.0
# 903  0.000000  0.000000  0.000000  0.000000  0.000000  0.149456  0.0
# 904  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.0
# 905  0.085613  0.000000  0.000000  0.000000  0.000000  0.000000  0.0
# 906  0.036692  0.000000  0.000000  0.041962  0.000000  0.000000  0.0
# 907  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.0
# 908  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.0
# 909  0.023227  0.000000  0.000000  0.000000  0.000000  0.000000  0.0
# 910  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.0
# 911  0.237326  0.000000  0.000000  0.000000  0.000000  0.000000  0.0
# 912  0.061957  0.000000  0.000000  0.000000  0.000000  0.000000  0.0
# 913  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.0
# 914  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.0
# 915  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.0
# 916  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.0
# 917  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.0
# 918  0.132382  0.000000  0.000000  0.000000  0.000000  0.000000  0.0
# 919  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.0
# 920  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.0
# 921  0.070411  0.000000  0.000000  0.000000  0.000000  0.000000  0.0
# 922  0.060120  0.000000  0.000000  0.000000  0.000000  0.048913  0.0
# 923  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.0
# 924  0.125367  0.000000  0.000000  0.000000  0.000000  0.000000  0.0
# 925  0.039154  0.111187  0.000000  0.134331  0.040654  0.000000  0.0
# 926  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.0
#
#            11        12        15    ...        world     worth     would  \
# 0    0.000000  0.000000  0.000000    ...     0.000000  0.000000  0.000000
# 1    0.056349  0.109757  0.000000    ...     0.076965  0.000000  0.073523
# 2    0.000000  0.000000  0.031826    ...     0.000000  0.000000  0.070488
# 3    0.000000  0.000000  0.000000    ...     0.000000  0.000000  0.032528
# 4    0.000000  0.000000  0.000000    ...     0.000000  0.054099  0.050976
# 5    0.000000  0.000000  0.000000    ...     0.000000  0.000000  0.000000
# 6    0.000000  0.000000  0.000000    ...     0.000000  0.000000  0.000000
# 7    0.000000  0.000000  0.000000    ...     0.000000  0.000000  0.000000
# 8    0.000000  0.000000  0.098644    ...     0.085763  0.000000  0.054619
# 9    0.000000  0.000000  0.000000    ...     0.065350  0.000000  0.000000
# 10   0.000000  0.000000  0.000000    ...     0.000000  0.080990  0.000000
# 11   0.000000  0.000000  0.000000    ...     0.000000  0.000000  0.212941
# 12   0.000000  0.000000  0.000000    ...     0.000000  0.000000  0.000000
# 13   0.000000  0.000000  0.000000    ...     0.000000  0.000000  0.127515
# 14   0.000000  0.000000  0.000000    ...     0.000000  0.000000  0.062586
# 15   0.000000  0.000000  0.000000    ...     0.000000  0.000000  0.000000
# 16   0.000000  0.000000  0.000000    ...     0.000000  0.000000  0.000000
# 17   0.000000  0.000000  0.000000    ...     0.000000  0.000000  0.077906
# 18   0.000000  0.000000  0.000000    ...     0.000000  0.000000  0.100885
# 19   0.000000  0.000000  0.000000    ...     0.000000  0.000000  0.196062
# 20   0.000000  0.000000  0.000000    ...     0.000000  0.000000  0.117139
# 21   0.000000  0.000000  0.000000    ...     0.000000  0.000000  0.062232
# 22   0.000000  0.000000  0.000000    ...     0.000000  0.000000  0.000000
# 23   0.000000  0.000000  0.000000    ...     0.062162  0.000000  0.039588
# 24   0.000000  0.000000  0.000000    ...     0.000000  0.000000  0.000000
# 25   0.000000  0.000000  0.000000    ...     0.000000  0.000000  0.106282
# 26   0.000000  0.000000  0.000000    ...     0.000000  0.000000  0.000000
# 27   0.000000  0.000000  0.000000    ...     0.000000  0.000000  0.000000
# 28   0.000000  0.018119  0.000000    ...     0.000000  0.000000  0.000000
# 29   0.000000  0.063593  0.000000    ...     0.000000  0.000000  0.000000
# ..        ...       ...       ...    ...          ...       ...       ...
# 897  0.000000  0.076802  0.000000    ...     0.000000  0.000000  0.068597
# 898  0.000000  0.000000  0.000000    ...     0.000000  0.000000  0.243887
# 899  0.000000  0.000000  0.000000    ...     0.000000  0.000000  0.000000
# 900  0.000000  0.000000  0.000000    ...     0.000000  0.000000  0.074612
# 901  0.000000  0.000000  0.000000    ...     0.000000  0.000000  0.041150
# 902  0.000000  0.000000  0.000000    ...     0.000000  0.000000  0.000000
# 903  0.000000  0.000000  0.000000    ...     0.000000  0.000000  0.000000
# 904  0.000000  0.000000  0.000000    ...     0.000000  0.000000  0.000000
# 905  0.000000  0.000000  0.000000    ...     0.000000  0.000000  0.000000
# 906  0.000000  0.000000  0.000000    ...     0.000000  0.000000  0.018895
# 907  0.000000  0.000000  0.000000    ...     0.000000  0.000000  0.000000
# 908  0.000000  0.000000  0.000000    ...     0.000000  0.000000  0.000000
# 909  0.000000  0.000000  0.043205    ...     0.000000  0.000000  0.071767
# 910  0.000000  0.000000  0.000000    ...     0.000000  0.000000  0.000000
# 911  0.000000  0.000000  0.000000    ...     0.000000  0.000000  0.081476
# 912  0.000000  0.000000  0.000000    ...     0.000000  0.000000  0.063811
# 913  0.000000  0.000000  0.000000    ...     0.000000  0.000000  0.000000
# 914  0.000000  0.000000  0.000000    ...     0.000000  0.000000  0.000000
# 915  0.000000  0.000000  0.000000    ...     0.000000  0.000000  0.000000
# 916  0.000000  0.000000  0.000000    ...     0.000000  0.000000  0.000000
# 917  0.000000  0.000000  0.000000    ...     0.000000  0.000000  0.000000
# 918  0.000000  0.000000  0.000000    ...     0.000000  0.000000  0.136344
# 919  0.000000  0.000000  0.080099    ...     0.000000  0.000000  0.000000
# 920  0.000000  0.000000  0.000000    ...     0.000000  0.000000  0.000000
# 921  0.000000  0.000000  0.000000    ...     0.000000  0.000000  0.217555
# 922  0.000000  0.000000  0.111829    ...     0.000000  0.000000  0.030959
# 923  0.000000  0.000000  0.000000    ...     0.000000  0.000000  0.000000
# 924  0.000000  0.000000  0.000000    ...     0.000000  0.000000  0.000000
# 925  0.000000  0.000000  0.000000    ...     0.000000  0.000000  0.161302
# 926  0.000000  0.000000  0.000000    ...     0.000000  0.000000  0.000000
#
#          year       yen  yesterday       yet    yield      york      zone
# 0    0.073258  0.000000   0.000000  0.000000  0.00000  0.000000  0.000000
# 1    0.027030  0.000000   0.000000  0.000000  0.00000  0.000000  0.000000
# 2    0.155483  0.000000   0.000000  0.000000  0.00000  0.000000  0.000000
# 3    0.000000  0.000000   0.000000  0.000000  0.00000  0.000000  0.000000
# 4    0.000000  0.000000   0.000000  0.000000  0.00000  0.048916  0.000000
# 5    0.215782  0.000000   0.000000  0.000000  0.00000  0.000000  0.000000
# 6    0.043690  0.000000   0.000000  0.000000  0.00000  0.000000  0.000000
# 7    0.135586  0.000000   0.000000  0.000000  0.00000  0.000000  0.000000
# 8    0.150597  0.000000   0.000000  0.000000  0.00000  0.000000  0.000000
# 9    0.183604  0.000000   0.000000  0.000000  0.00000  0.000000  0.000000
# 10   0.042083  0.000000   0.000000  0.000000  0.00000  0.000000  0.000000
# 11   0.000000  0.000000   0.094107  0.000000  0.00000  0.000000  0.000000
# 12   0.000000  0.000000   0.000000  0.000000  0.00000  0.000000  0.000000
# 13   0.000000  0.000000   0.000000  0.136289  0.00000  0.000000  0.000000
# 14   0.000000  0.000000   0.000000  0.000000  0.00000  0.000000  0.142597
# 15   0.000000  0.000000   0.000000  0.000000  0.00000  0.000000  0.000000
# 16   0.000000  0.000000   0.000000  0.000000  0.00000  0.000000  0.000000
# 17   0.000000  0.000000   0.000000  0.000000  0.00000  0.000000  0.000000
# 18   0.000000  0.000000   0.000000  0.000000  0.00000  0.000000  0.000000
# 19   0.000000  0.000000   0.075817  0.000000  0.00000  0.000000  0.000000
# 20   0.215321  0.000000   0.000000  0.000000  0.00000  0.000000  0.000000
# 21   0.000000  0.000000   0.000000  0.000000  0.00000  0.000000  0.000000
# 22   0.000000  0.000000   0.000000  0.000000  0.00000  0.000000  0.000000
# 23   0.174647  0.169337   0.000000  0.000000  0.00000  0.000000  0.000000
# 24   0.000000  0.000000   0.000000  0.000000  0.00000  0.000000  0.000000
# 25   0.000000  0.000000   0.164396  0.000000  0.00000  0.000000  0.000000
# 26   0.000000  0.000000   0.000000  0.000000  0.00000  0.000000  0.000000
# 27   0.000000  0.000000   0.000000  0.000000  0.00000  0.000000  0.000000
# 28   0.000000  0.000000   0.000000  0.000000  0.00939  0.000000  0.000000
# 29   0.093964  0.000000   0.000000  0.000000  0.00000  0.000000  0.000000
# ..        ...       ...        ...       ...      ...       ...       ...
# 897  0.000000  0.000000   0.000000  0.000000  0.00000  0.000000  0.000000
# 898  0.000000  0.347738   0.000000  0.000000  0.00000  0.000000  0.000000
# 899  0.000000  0.000000   0.000000  0.000000  0.00000  0.000000  0.000000
# 900  0.041145  0.159575   0.000000  0.000000  0.00000  0.000000  0.000000
# 901  0.000000  0.117346   0.000000  0.000000  0.00000  0.000000  0.000000
# 902  0.000000  0.000000   0.000000  0.000000  0.00000  0.000000  0.000000
# 903  0.000000  0.000000   0.146323  0.000000  0.00000  0.000000  0.000000
# 904  0.000000  0.000000   0.000000  0.000000  0.00000  0.000000  0.000000
# 905  0.000000  0.000000   0.136389  0.000000  0.00000  0.000000  0.000000
# 906  0.020840  0.269412   0.058454  0.000000  0.00000  0.072527  0.043051
# 907  0.000000  0.000000   0.000000  0.000000  0.00000  0.000000  0.000000
# 908  0.000000  0.118987   0.000000  0.000000  0.00000  0.000000  0.000000
# 909  0.026384  0.000000   0.037003  0.000000  0.00000  0.000000  0.000000
# 910  0.000000  0.079670   0.000000  0.000000  0.00000  0.000000  0.000000
# 911  0.000000  0.000000   0.000000  0.000000  0.00000  0.000000  0.000000
# 912  0.023459  0.000000   0.032901  0.000000  0.00000  0.000000  0.000000
# 913  0.000000  0.000000   0.000000  0.000000  0.00000  0.000000  0.000000
# 914  0.000000  0.000000   0.000000  0.000000  0.00000  0.000000  0.569126
# 915  0.000000  0.000000   0.000000  0.000000  0.00000  0.000000  0.000000
# 916  0.000000  0.000000   0.000000  0.000000  0.00000  0.000000  0.000000
# 917  0.000000  0.356811   0.000000  0.000000  0.00000  0.000000  0.000000
# 918  0.100249  0.000000   0.000000  0.000000  0.00000  0.000000  0.103550
# 919  0.000000  0.252941   0.000000  0.000000  0.00000  0.000000  0.000000
# 920  0.000000  0.000000   0.000000  0.000000  0.00000  0.000000  0.000000
# 921  0.000000  0.000000   0.000000  0.000000  0.00000  0.000000  0.000000
# 922  0.034145  0.176570   0.095775  0.000000  0.00000  0.000000  0.000000
# 923  0.000000  0.000000   0.000000  0.000000  0.00000  0.000000  0.000000
# 924  0.071203  0.000000   0.000000  0.138003  0.00000  0.000000  0.000000
# 925  0.022238  0.000000   0.062375  0.000000  0.00000  0.000000  0.000000
# 926  0.000000  0.000000   0.000000  0.000000  0.00000  0.000000  0.000000
#
# [927 rows x 795 columns]

# %%
mydata.iloc[898,1]
# Out:
# 'Sumita says further yen rise would adversely affect Japanese economy Sumita says further yen rise would adversely affect Japanese economy'

# %%
tfidf_df.loc[898, ['yen', 'japan']]
# Out:
# yen      0.347738
# japan    0.000000
# Name: 898, dtype: float64

# %%
list(tfidf_df.columns)
# Out:
# ["''",
#  '--',
#  '...',
#  '1',
#  '1.5',
#  '10',
#  '100',
#  '11',
#  '12',
#  '15',
#  '15.8',
#  '150',
#  '16',
#  '17',
#  '18',
#  '1984',
#  '1985',
#  '1985.',
#  '1986',
#  '1986.',
#  '1987',
#  '1988',
#  '2',
#  '2.5',
#  '20',
#  '200',
#  '22',
#  '24',
#  '25',
#  '3.5',
#  '30',
#  '300',
#  '31',
#  '40',
#  '50',
#  '500',
#  '60',
#  '70',
#  '9-13/16',
#  '9-7/8',
#  '``',
#  'able',
#  'accord',
#  'according',
#  'account',
#  'action',
#  'activity',
#  'add',
#  'added',
#  'adding',
#  'addition',
#  'additional',
#  'adjustment',
#  'administration',
#  'advance',
#  'affecting',
#  'afternoon',
#  'agency',
#  'ago',
#  'agreed',
#  'agreement',
#  'ahead',
#  'aimed',
#  'allow',
#  'allowed',
#  'almost',
#  'already',
#  'also',
#  'although',
#  'american',
#  'among',
#  'amount',
#  'analyst',
#  'announced',
#  'annual',
#  'another',
#  'appropriate',
#  'april',
#  'arab',
#  'arabia',
#  'area',
#  'around',
#  'asked',
#  'asset',
#  'assistance',
#  'association',
#  'attempt',
#  'authority',
#  'available',
#  'average',
#  'averaged',
#  'back',
#  'baker',
#  'balance',
#  'band',
#  'bank',
#  'banker',
#  'banking',
#  'barrel',
#  'base',
#  'based',
#  'basis',
#  'bbl',
#  'become',
#  'began',
#  'begin',
#  'beginning',
#  'behind',
#  'belief',
#  'believe',
#  'believed',
#  'benefit',
#  'better',
#  'bid',
#  'big',
#  'bill',
#  'billion',
#  'board',
#  'bond',
#  'boost',
#  'bought',
#  'bpd',
#  'brazil',
#  'bring',
#  'brings',
#  'britain',
#  'british',
#  'brought',
#  'budget',
#  'bundesbank',
#  'business',
#  'buy',
#  'buyer',
#  'buying',
#  'call',
#  'called',
#  'came',
#  'canada',
#  'canadian',
#  'capacity',
#  'capital',
#  'cash',
#  'cause',
#  'caused',
#  'ceiling',
#  'cent',
#  'central',
#  'chairman',
#  'chance',
#  'change',
#  'changed',
#  'chief',
#  'circulation',
#  'clear',
#  'close',
#  'closed',
#  'closely',
#  'co',
#  'coast',
#  'come',
#  'coming',
#  'comment',
#  'commercial',
#  'commitment',
#  'committee',
#  'commodity',
#  'common',
#  'company',
#  'compare',
#  'compared',
#  'completed',
#  'comprising',
#  'concern',
#  'condition',
#  'conference',
#  'congress',
#  'considered',
#  'consumer',
#  'consumption',
#  'continue',
#  'continued',
#  'contract',
#  'control',
#  'cooperate',
#  'cooperation',
#  'corp',
#  'cost',
#  'could',
#  'council',
#  'country',
#  'credit',
#  'crisis',
#  'crude',
#  'ct',
#  'cubic',
#  'currency',
#  'current',
#  'currently',
#  'customer',
#  'cut',
#  'daily',
#  'damage',
#  'data',
#  'day',
#  'de',
#  'deal',
#  'dealer',
#  'debt',
#  'december',
#  'decision',
#  'decline',
#  'declined',
#  'defend',
#  'deficit',
#  'demand',
#  'department',
#  'deposit',
#  'deputy',
#  'despite',
#  'detail',
#  'development',
#  'difficult',
#  'director',
#  'discount',
#  'discus',
#  'discussion',
#  'distillate',
#  'dlr',
#  'dlrs',
#  'dollar',
#  'domestic',
#  'drain',
#  'drilling',
#  'drop',
#  'dropped',
#  'due',
#  'earlier',
#  'early',
#  'earthquake',
#  'ease',
#  'eased',
#  'east',
#  'economic',
#  'economist',
#  'economy',
#  'ecuador',
#  'effect',
#  'effective',
#  'effort',
#  'eight',
#  'emergency',
#  'end',
#  'ended',
#  'energy',
#  'england',
#  'enough',
#  'equivalent',
#  'especially',
#  'estimate',
#  'estimated',
#  'europe',
#  'european',
#  'even',
#  'exchange',
#  'exchequer',
#  'executive',
#  'expect',
#  'expectation',
#  'expected',
#  'expects',
#  'expenditure',
#  'exploration',
#  'export',
#  'exporter',
#  'exxon',
#  'face',
#  'facility',
#  'fact',
#  'factor',
#  'fall',
#  'falling',
#  'far',
#  'fear',
#  'february',
#  'fed',
#  'federal',
#  'fee',
#  'fell',
#  'field',
#  'figure',
#  'final',
#  'finance',
#  'financial',
#  'find',
#  'firm',
#  'first',
#  'fiscal',
#  'five',
#  'fixed',
#  'flow',
#  'fluctuation',
#  'following',
#  'foot',
#  'force',
#  'forecast',
#  'foreign',
#  'forward',
#  'foster',
#  'four',
#  'franc',
#  'france',
#  'french',
#  'friday',
#  'fuel',
#  'full',
#  'fund',
#  'fundamental',
#  'future',
#  'gain',
#  'gas',
#  'gasoline',
#  'gave',
#  'general',
#  'generally',
#  'german',
#  'germany',
#  'get',
#  'give',
#  'given',
#  'go',
#  'goal',
#  'going',
#  'good',
#  'government',
#  'governor',
#  'grade',
#  'greater',
#  'gross',
#  'group',
#  'growing',
#  'growth',
#  'gulf',
#  'half',
#  'hand',
#  'hard',
#  'heavy',
#  'held',
#  'help',
#  'high',
#  'higher',
#  'hit',
#  'hold',
#  'holding',
#  'hope',
#  'house',
#  'however',
#  'huge',
#  'imbalance',
#  'impact',
#  'import',
#  'important',
#  'improvement',
#  'inc',
#  'incentive',
#  'include',
#  'including',
#  'increase',
#  'increased',
#  'increasing',
#  'index',
#  'industrial',
#  'industry',
#  'inflation',
#  'instead',
#  'institute',
#  'interest',
#  'intermediate',
#  'international',
#  'intervene',
#  'intervened',
#  'intervention',
#  'interview',
#  'investment',
#  'investor',
#  'iran',
#  'iranian',
#  'iraq',
#  'issue',
#  'issued',
#  'james',
#  'january',
#  'japan',
#  'japanese',
#  'john',
#  'joint',
#  'june',
#  'keep',
#  'key',
#  'kiichi',
#  'kuwait',
#  'large',
#  'largely',
#  'largest',
#  'last',
#  'late',
#  'later',
#  'latest',
#  'lawson',
#  'le',
#  'lead',
#  'leading',
#  'least',
#  'led',
#  'left',
#  'lending',
#  'level',
#  'light',
#  'like',
#  'likely',
#  'limit',
#  'line',
#  'liquidity',
#  'little',
#  'loan',
#  'local',
#  'london',
#  'long',
#  'longer',
#  'look',
#  'looking',
#  'loss',
#  'lost',
#  'low',
#  'lower',
#  'lt',
#  'ltd',
#  'made',
#  'main',
#  'maintain',
#  'major',
#  'make',
#  'making',
#  'many',
#  'march',
#  'mark',
#  'market',
#  'maturing',
#  'may',
#  'mean',
#  'measure',
#  'meet',
#  'meeting',
#  'member',
#  'met',
#  'might',
#  'mile',
#  'minister',
#  'ministry',
#  'miyazawa',
#  'mln',
#  'monday',
#  'monetary',
#  'money',
#  'month',
#  'morning',
#  'move',
#  'movement',
#  'much',
#  'must',
#  "n't",
#  'narrow',
#  'nation',
#  'national',
#  'natural',
#  'near',
#  'nearly',
#  'necessary',
#  'need',
#  'needed',
#  'net',
#  'new',
#  'news',
#  'next',
#  'night',
#  'nine',
#  'north',
#  'northern',
#  'note',
#  'noted',
#  'number',
#  'offer',
#  'offered',
#  'official',
#  'offset',
#  'offshore',
#  'oil',
#  'one',
#  'opec',
#  'open',
#  'opened',
#  'operating',
#  'operation',
#  'operator',
#  'option',
#  'order',
#  'outlook',
#  'output',
#  'outright',
#  'outside',
#  'overall',
#  'overnight',
#  'overseas',
#  'pacific',
#  'package',
#  'pact',
#  'paper',
#  'paris',
#  'parliament',
#  'part',
#  'partly',
#  'partner',
#  'party',
#  'past',
#  'pay',
#  'payment',
#  'pct',
#  'people',
#  'per',
#  'performance',
#  'period',
#  'petroleum',
#  'pipeline',
#  'place',
#  'plan',
#  'planned',
#  'plc',
#  'point',
#  'policy',
#  'political',
#  'port',
#  'position',
#  'possible',
#  'posted',
#  'potential',
#  'pound',
#  'prepared',
#  'present',
#  'president',
#  'press',
#  'pressure',
#  'prevent',
#  'previous',
#  'previously',
#  'price',
#  'prime',
#  'private',
#  'probably',
#  'problem',
#  'produce',
#  'produced',
#  'producer',
#  'producing',
#  'product',
#  'production',
#  'profit',
#  'program',
#  'project',
#  'proposal',
#  'proposed',
#  'prospect',
#  'provide',
#  'provided',
#  'public',
#  'purchase',
#  'purchased',
#  'push',
#  'put',
#  'quarter',
#  'question',
#  'quota',
#  'quoted',
#  'raise',
#  'raised',
#  'range',
#  'rate',
#  'rather',
#  'reached',
#  'reagan',
#  'real',
#  'reason',
#  'recent',
#  'recently',
#  'record',
#  'recovery',
#  'reduce',
#  'reduced',
#  'reduction',
#  'refinery',
#  'refining',
#  'reflect',
#  'refused',
#  'region',
#  'remain',
#  'remained',
#  'remains',
#  'remark',
#  'report',
#  'reported',
#  'reporter',
#  'representative',
#  'repurchase',
#  'requirement',
#  'research',
#  'reserve',
#  'resource',
#  'respectively',
#  'response',
#  'result',
#  'return',
#  'reuters',
#  'revenue',
#  'review',
#  'revised',
#  'right',
#  'rise',
#  'rising',
#  'risk',
#  'robert',
#  'role',
#  'rose',
#  'round',
#  'rule',
#  'run',
#  'sale',
#  'saudi',
#  'saw',
#  'say',
#  'saying',
#  'scheduled',
#  'sea',
#  'second',
#  'secretary',
#  'sector',
#  'security',
#  'see',
#  'seen',
#  'sell',
#  'selling',
#  'senior',
#  'sentiment',
#  'september',
#  'service',
#  'session',
#  'set',
#  'seven',
#  'several',
#  'share',
#  'sharp',
#  'sharply',
#  'shell',
#  'shift',
#  'ship',
#  'shipment',
#  'short',
#  'short-term',
#  'shortage',
#  'show',
#  'showed',
#  'side',
#  'sign',
#  'signed',
#  'significant',
#  'similar',
#  'since',
#  'situation',
#  'six',
#  'slide',
#  'slightly',
#  'slow',
#  'small',
#  'smaller',
#  'sold',
#  'soon',
#  'source',
#  'south',
#  'special',
#  'specific',
#  'speech',
#  'spending',
#  'spokesman',
#  'spot',
#  'stabilise',
#  'stability',
#  'stabilize',
#  'stable',
#  'stand',
#  'standard',
#  'start',
#  'state',
#  'statement',
#  'step',
#  'sterling',
#  'stg',
#  'still',
#  'stimulate',
#  'stock',
#  'stop',
#  'strong',
#  'study',
#  'subsidiary',
#  'substantial',
#  'sumita',
#  'supply',
#  'support',
#  'surplus',
#  'survey',
#  'system',
#  'take',
#  'taken',
#  'taking',
#  'talk',
#  'tanker',
#  'target',
#  'tax',
#  'temporary',
#  'tender',
#  'term',
#  'test',
#  'texas',
#  'think',
#  'third',
#  'though',
#  'three',
#  'time',
#  'today',
#  'tokyo',
#  'told',
#  'tomorrow',
#  'took',
#  'top',
#  'total',
#  'towards',
#  'trade',
#  'traded',
#  'trader',
#  'trading',
#  'transaction',
#  'treasury',
#  'trend',
#  'trust',
#  'tuesday',
#  'two',
#  'u.k.',
#  'u.s.',
#  'unchanged',
#  'underlying',
#  'union',
#  'unit',
#  'united',
#  'unless',
#  'unlikely',
#  'use',
#  'used',
#  'using',
#  'value',
#  'venezuela',
#  'via',
#  'view',
#  'volume',
#  'want',
#  'wanted',
#  'washington',
#  'way',
#  'weak',
#  'wednesday',
#  'week',
#  'weekly',
#  'well',
#  'west',
#  'western',
#  'whether',
#  'within',
#  'without',
#  'work',
#  'working',
#  'world',
#  'worth',
#  'would',
#  'year',
#  'yen',
#  'yesterday',
#  'yet',
#  'yield',
#  'york',
#  'zone']

# %% [markdown]
# # Sentiment Analysis with nltk

# %%
# nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\DELL\AppData\Roaming\nltk_data...
# True

# %%
from nltk.sentiment.vader import SentimentIntensityAnalyzer
analyzer=SentimentIntensityAnalyzer()
# Out:
# C:\Users\DELL\Anaconda3\lib\site-packages\nltk\twitter\__init__.py:20: UserWarning: The twython library has not been installed. Some functionality from the twitter package will not be available.
#   warnings.warn("The twython library has not been installed. "

# %%
sentences = ["VADER is smart, handsome, and funny.",      # positive sentence example
            "VADER is not smart, handsome, nor funny.",   # negation sentence example
            "VADER is smart, handsome, and funny!",       # punctuation emphasis handled correctly (sentiment intensity adjusted)
            "VADER is very smart, handsome, and funny.",  # booster words handled correctly (sentiment intensity adjusted)
            "VADER is VERY SMART, handsome, and FUNNY.",  # emphasis for ALLCAPS handled
            "VADER is VERY SMART, handsome, and FUNNY!!!",# combination of signals - VADER appropriately adjusts intensity
            "VADER is VERY SMART, uber handsome, and FRIGGIN FUNNY!!!",# booster words & punctuation make this close to ceiling for score
            "The book was good.",                                     # positive sentence
            "The book was kind of good.",                 # qualified positive sentence is handled correctly (intensity adjusted)
        '''The plot was good, but the characters are uncompelling and 
             the dialog is not great.''', # mixed negation sentence
            "At least it isn't a horrible book.",         # negated negative sentence with contraction
            "Make sure you :) or :D today!",              # emoticons handled
            "Today SUX!",                                 # negative slang with capitalization emphasis
            "Today only kinda sux! But I'll get by, lol"  # mixed sentiment example with slang and constrastive conjunction "but"
             ]


for sentence in sentences:
    vs = analyzer.polarity_scores(sentence)
    print(sentence, str(vs))
# Out:
# VADER is smart, handsome, and funny. {'neg': 0.0, 'neu': 0.254, 'pos': 0.746, 'compound': 0.8316}
# VADER is not smart, handsome, nor funny. {'neg': 0.646, 'neu': 0.354, 'pos': 0.0, 'compound': -0.7424}
# VADER is smart, handsome, and funny! {'neg': 0.0, 'neu': 0.248, 'pos': 0.752, 'compound': 0.8439}
# VADER is very smart, handsome, and funny. {'neg': 0.0, 'neu': 0.299, 'pos': 0.701, 'compound': 0.8545}
# VADER is VERY SMART, handsome, and FUNNY. {'neg': 0.0, 'neu': 0.246, 'pos': 0.754, 'compound': 0.9227}
# VADER is VERY SMART, handsome, and FUNNY!!! {'neg': 0.0, 'neu': 0.233, 'pos': 0.767, 'compound': 0.9342}
# VADER is VERY SMART, uber handsome, and FRIGGIN FUNNY!!! {'neg': 0.0, 'neu': 0.294, 'pos': 0.706, 'compound': 0.9469}
# The book was good. {'neg': 0.0, 'neu': 0.508, 'pos': 0.492, 'compound': 0.4404}
# The book was kind of good. {'neg': 0.0, 'neu': 0.657, 'pos': 0.343, 'compound': 0.3832}
# The plot was good, but the characters are uncompelling and
#              the dialog is not great. {'neg': 0.327, 'neu': 0.579, 'pos': 0.094, 'compound': -0.7042}
# At least it isn't a horrible book. {'neg': 0.0, 'neu': 0.637, 'pos': 0.363, 'compound': 0.431}
# Make sure you :) or :D today! {'neg': 0.0, 'neu': 0.294, 'pos': 0.706, 'compound': 0.8633}
# Today SUX! {'neg': 0.779, 'neu': 0.221, 'pos': 0.0, 'compound': -0.5461}
# Today only kinda sux! But I'll get by, lol {'neg': 0.179, 'neu': 0.569, 'pos': 0.251, 'compound': 0.2228}

# %% [markdown]
# # Language Correction, Detection and Translation with TextBlob

# %%
# !pip install textblob
# Out:
# Collecting textblob
#   Downloading https://files.pythonhosted.org/packages/60/f0/1d9bfcc8ee6b83472ec571406bd0dd51c0e6330ff1a51b2d29861d389e85/textblob-0.15.3-py2.py3-none-any.whl (636kB)
# Requirement already satisfied: nltk>=3.1 in c:\users\dell\anaconda3\lib\site-packages (from textblob) (3.2.2)
# Requirement already satisfied: six in c:\users\dell\anaconda3\lib\site-packages (from nltk>=3.1->textblob) (1.10.0)
# Installing collected packages: textblob
# Successfully installed textblob-0.15.3

# %%
from textblob import TextBlob

# %%
b = TextBlob("I havv goood color !")
b.correct()
# Out:
# TextBlob("I have good color !")

# %%
chinese_blob = TextBlob(u"美丽优于丑陋")

# %%
chinese_blob.translate(from_lang="zh-CN", to='en')
# Out:
# TextBlob("Beauty is better than ugly")

# %%
b = TextBlob(u"بسيط هو أفضل من مجمع")

# %%
b.detect_language()
# Out:
# 'ar'

# %% [markdown]
# # POS Tagging

# %% [markdown]
# source : https://stackoverflow.com/questions/1833252/java-stanford-nlp-part-of-speech-labels
#
# * CC: conjunction, coordinating
#
#     & 'n and both but either et for less minus neither nor or plus so
#     therefore times v. versus vs. whether yet
#
# * CD: numeral, cardinal
#
#     mid-1890 nine-thirty forty-two one-tenth ten million 0.5 one forty-
#     seven 1987 twenty '79 zero two 78-degrees eighty-four IX '60s .025
#     fifteen 271,124 dozen quintillion DM2,000 ...
#
# * DT: determiner
#
#     all an another any both del each either every half la many much nary
#     neither no some such that the them these this those
#
# * EX: existential there
#     there
#
# * FW: foreign word
#
#     gemeinschaft hund ich jeux habeas Haementeria Herr K'ang-si vous
#     lutihaw alai je jour objets salutaris fille quibusdam pas trop Monte
#     terram fiche oui corporis ...
#
# * IN: preposition or conjunction, subordinating
#
#     astride among uppon whether out inside pro despite on by throughout
#     below within for towards near behind atop around if like until below
#     next into if beside ...
#
# * JJ: adjective or numeral, ordinal
#
#     third ill-mannered pre-war regrettable oiled calamitous first separable
#     ectoplasmic battery-powered participatory fourth still-to-be-named
#     multilingual multi-disciplinary ...
#
# * JJR: adjective, comparative
#
#     bleaker braver breezier briefer brighter brisker broader bumper busier
#     calmer cheaper choosier cleaner clearer closer colder commoner costlier
#     cozier creamier crunchier cuter ...
#
# * JJS: adjective, superlative
#
#     calmest cheapest choicest classiest cleanest clearest closest commonest
#     corniest costliest crassest creepiest crudest cutest darkest deadliest
#     dearest deepest densest dinkiest ...
#
# * LS: list item marker
#
#     A A. B B. C C. D E F First G H I J K One SP-44001 SP-44002 SP-44005
#     SP-44007 Second Third Three Two * a b c d first five four one six three
#     two
#
# * MD: modal auxiliary
#
#     can cannot could couldn't dare may might must need ought shall should
#     shouldn't will would
#
# * NN: noun, common, singular or mass
#
#     common-carrier cabbage knuckle-duster Casino afghan shed thermostat
#     investment slide humour falloff slick wind hyena override subhumanity
#     machinist ...
#
# * NNS: noun, common, plural
#
#     undergraduates scotches bric-a-brac products bodyguards facets coasts
#     divestitures storehouses designs clubs fragrances averages
#     subjectivists apprehensions muses factory-jobs ...
#
# * NNP: noun, proper, singular
#
#     Motown Venneboerger Czestochwa Ranzer Conchita Trumplane Christos
#     Oceanside Escobar Kreisler Sawyer Cougar Yvette Ervin ODI Darryl CTCA
#     Shannon A.K.C. Meltex Liverpool ...
#
# * NNPS: noun, proper, plural
#
#     Americans Americas Amharas Amityvilles Amusements Anarcho-Syndicalists
#     Andalusians Andes Andruses Angels Animals Anthony Antilles Antiques
#     Apache Apaches Apocrypha ...
#
# * PDT: pre-determiner
#
#     all both half many quite such sure this
#
# * POS: genitive marker
#     ' 's
#
# * PRP: pronoun, personal
#
#     hers herself him himself hisself it itself me myself one oneself ours
#     ourselves ownself self she thee theirs them themselves they thou thy us
#
# * PRP$': pronoun, possessive
#
#     her his mine my our ours their thy your
#
# * RB: adverb
#
#     occasionally unabatingly maddeningly adventurously professedly
#     stirringly prominently technologically magisterially predominately
#     swiftly fiscally pitilessly ...
#
# * RBR: adverb, comparative
#
#     further gloomier grander graver greater grimmer harder harsher
#     healthier heavier higher however larger later leaner lengthier less-
#     perfectly lesser lonelier longer louder lower more ...
#
# * RBS: adverb, superlative
#
#     best biggest bluntest earliest farthest first furthest hardest
#     heartiest highest largest least less most nearest second tightest worst
#
# * RP: particle
#
#     aboard about across along apart around aside at away back before behind
#     by crop down ever fast for forth from go high i.e. in into just later
#     low more off on open out over per pie raising start teeth that through
#     under unto up up-pp upon whole with you
#
# * SYM: symbol
#
#     % & ' '' ''. ) ). * + ,. < = > @ A[fj] U.S U.S.S.R * ** ***
#
# * TO: "to" as preposition or infinitive marker
#
#     to
#
# * UH: interjection
#
#     Goodbye Goody Gosh Wow Jeepers Jee-sus Hubba Hey Kee-reist Oops amen
#     huh howdy uh dammit whammo shucks heck anyways whodunnit honey golly
#     man baby diddle hush sonuvabitch ...
#
# * VB: verb, base form
#
#     ask assemble assess assign assume atone attention avoid bake balkanize
#     bank begin behold believe bend benefit bevel beware bless boil bomb
#     boost brace break bring broil brush build ...
#
# * VBD: verb, past tense
#
#     dipped pleaded swiped regummed soaked tidied convened halted registered
#     cushioned exacted snubbed strode aimed adopted belied figgered
#     speculated wore appreciated contemplated ...
#
# * VBG: verb, present participle or gerund
#
#     telegraphing stirring focusing angering judging stalling lactating
#     hankerin' alleging veering capping approaching traveling besieging
#     encrypting interrupting erasing wincing ...
#
# * VBN: verb, past participle
#
#     multihulled dilapidated aerosolized chaired languished panelized used
#     experimented flourished imitated reunifed factored condensed sheared
#     unsettled primed dubbed desired ...
#
# * VBP: verb, present tense, not 3rd person singular
#
#     predominate wrap resort sue twist spill cure lengthen brush terminate
#     appear tend stray glisten obtain comprise detest tease attract
#     emphasize mold postpone sever return wag ...
#
# * VBZ: verb, present tense, 3rd person singular
#
#     bases reconstructs marks mixes displeases seals carps weaves snatches
#     slumps stretches authorizes smolders pictures emerges stockpiles
#     seduces fizzes uses bolsters slaps speaks pleads ...
#
# * WDT: WH-determiner
#     that what whatever which whichever
#
# * WP: WH-pronoun
#
#     that what whatever whatsoever which who whom whosoever
#
# * WP$: WH-pronoun, possessive
#
#     whose
#
# * WRB: Wh-adverb
#
#     how however whence whenever where whereby whereever wherein whereof why

# %%
sentence = "We hope you love your sleepycat mattress. Welcom to the sleepycat community."

# %%
# nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping taggers\averaged_perceptron_tagger.zip.
# True

# %%
nltk.pos_tag(nltk.word_tokenize(sentence))
# Out:
# [('We', 'PRP'),
#  ('hope', 'VBP'),
#  ('you', 'PRP'),
#  ('love', 'VB'),
#  ('your', 'PRP$'),
#  ('sleepycat', 'NN'),
#  ('mattress', 'NN'),
#  ('.', '.'),
#  ('Welcom', 'NNP'),
#  ('to', 'TO'),
#  ('the', 'DT'),
#  ('sleepycat', 'NN'),
#  ('community', 'NN'),
#  ('.', '.')]
