# %% [markdown]
# ### using urllib to read html data from webpages

# %%
from urllib.request import urlopen

# %%
x = urlopen('https://www.bbc.co.uk/')
k=x.read()

# %%
k
# Out:
# b'<!DOCTYPE html>\n<!--[if lte IE 9]>\n  <html lang="en-GB" class="no-js no-flexbox no-flexboxlegacy b-reith-sans-font">\n<![endif]-->\n<!--[if gt IE 9]><!-->\n  <html lang="en-GB" class="no-js b-reith-sans-font b-reith-serif-font">\n<!--<![endif]-->\n<head>\n    <meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1"/><script type="text/javascript">\n      var _sf_startpt = (new Date()).getTime();\n    </script><meta content="text/html; charset=UTF-8" http-equiv="Content-Type"><meta content="The best of the BBC, with the latest news and sport headlines, weather, TV &amp; radio highlights and much more from across the whole of BBC Online" name="description"><meta content="BBC, British Broadcasting Corporation, BBCi, News, Sport, iPlayer, TV, Radio, Food, Music, Business, Arts, Bitesize, Lifestyle, Entertainment, Headlines" name="keywords"><meta property="og:title" content="BBC - Home"><meta property="og:type" content="website"><meta property="og:description" content="The best o
# ...

# %%
parts=str(k).split("<a href=")

# %%
parts[1:5]
# Out:
# ['"https://www.bbc.com/">Home</a></li><li class="orb-nav-newsdotcom">',
#  '"https://www.bbc.com/news">News</a></li><li class="orb-nav-sport">',
#  '"https://www.bbc.com/sport">Sport</a></li><li class="orb-nav-weather">',
#  '"https://www.bbc.com/weather">Weather</a></li><li class="orb-nav-shop">']

# %%
for part in parts[1:5]:
    print(part.split('"')[1])
# Out:
# https://www.bbc.com/
# https://www.bbc.com/news
# https://www.bbc.com/sport
# https://www.bbc.com/weather

# %%
in_links=[]
parts=str(k).split("<a href=")
for part in parts:
    link=part.split('"')[1]
    if "www.bbc" not in link:continue
    else:
        in_links.append(link)
in_links
# Out:
# ['https://www.bbc.com/',
#  'https://www.bbc.com/news',
#  'https://www.bbc.com/sport',
#  'https://www.bbc.com/weather',
#  'https://www.bbc.com/reel/',
#  'https://www.bbc.com/travel/',
#  'https://www.bbc.com/capital/',
#  'https://www.bbc.com/culture/',
#  'https://www.bbc.com/future/',
#  'https://www.bbc.co.uk/sounds',
#  'https://www.bbc.co.uk/cbbc',
#  'https://www.bbc.co.uk/cbeebies',
#  'https://www.bbc.com/food/',
#  'https://www.bbc.com/bitesize',
#  'https://www.bbc.co.uk/arts/',
#  'https://www.bbc.co.uk/makeitdigital',
#  'https://www.bbc.co.uk/taster',
#  'https://www.bbc.com/nature/',
#  'https://www.bbc.co.uk/news/localnews',
#  'https://www.bbc.co.uk/tv/',
#  'https://www.bbc.co.uk/radio/',
#  'https://www.bbc.co.uk',
#  'https://www.bbc.co.uk',
#  'https://www.bbc.co.uk/news',
#  'https://www.bbc.co.uk/sport',
#  'https://www.bbc.co.uk/weather',
#  'https://www.bbc.co.uk/iplayer',
#  'https://www.bbc.co.uk/sounds',
#  'https://www.bbc.co.uk/cbbc',
# ...

# %%
len(in_links)
# Out:
# 152

# %%
in_links=set(in_links)
len(in_links)
# Out:
# 125

# %% [markdown]
# ### Accessing google search with urllib

# %%
# url='https://www.google.com/search?q=python+programming+tutorials'
# resp = urlopen(url)
# respData = resp.read()
# print(respData)

# %%
from urllib.request import Request
url = 'https://www.google.com/search?q=python+programming+tutorials'

headers = {}
headers['User-Agent'] = r"Mozilla/5.0 (X11; Linux i686) AppleWebKit/537.17 (KHTML, like Gecko) Chrome/24.0.1312.27 Safari/537.17"

req = Request(url, headers = headers)
resp = urlopen(req)
respData = resp.read()

# %%
print(respData)
# Out:
# b'<!doctype html><html itemscope="" itemtype="http://schema.org/SearchResultsPage" lang="en-IN"><head><meta content="/images/branding/googleg/1x/googleg_standard_color_128dp.png" itemprop="image"><meta content="origin" name="referrer"><title>python programming tutorials - Google Search</title><script nonce="7KNicM3bhskk/S5BdGLlXw==">(function(){window.google={kEI:\'W2jOXL6INYjchwPk9ZQg\',kEXPI:\'31\',authuser:0,kscs:\'c9c918f0_W2jOXL6INYjchwPk9ZQg\',kGL:\'IN\'};google.sn=\'web\';google.kHL=\'en-IN\';})();(function(){google.lc=[];google.li=0;google.getEI=function(a){for(var b;a&&(!a.getAttribute||!(b=a.getAttribute("eid")));)a=a.parentNode;return b||google.kEI};google.getLEI=function(a){for(var b=null;a&&(!a.getAttribute||!(b=a.getAttribute("leid")));)a=a.parentNode;return b};google.https=function(){return"https:"==window.location.protocol};google.ml=function(){return null};google.time=function(){return(new Date).getTime()};google.log=function(a,b,e,c,g){if(a=google.logUrl(a,b,e,c,g))
# ...

# %%
in_links=[]
parts=str(respData).split("<a href=")
for part in parts:
    link=part.split('"')[1]
    if "www." not in link:continue
    else:
        in_links.append(link)
in_links
# Out:
# ['https://www.google.com/webhp?hl=en&amp;sa=X&amp;ved=0ahUKEwj-oY-_yIPiAhUI7mEKHeQ6BQQQPAgH',
#  'https://www.guru99.com/python-tutorials.html',
#  'https://www.youtube.com/watch?v=_uQrJ0TkZlc',
#  'https://www.youtube.com/watch?v=yE9v9rt6ziw',
#  'https://www.youtube.com/watch?v=rfscVS0vtbw',
#  'https://www.guru99.com/python-tutorials.html',
#  'https://www.tutorialspoint.com/python/',
#  'https://www.programiz.com/python-programming',
#  'https://www.python.org/about/gettingstarted/',
#  'https://www.learnpython.org/',
#  'https://www.w3schools.com/python/']

# %% [markdown]
# ### Parsing with BeautifulSoup

# %%
from bs4 import BeautifulSoup

# %%
mydata=urlopen("https://in.finance.yahoo.com/q?s=SBIN.BO").read()
soup = BeautifulSoup(mydata,'lxml')

# %%
soup
# Out:
# <!DOCTYPE html>
# ...

# %%
soup.findAll("a")
# Out:
# [<a class="Bgpx(0) Bgr(nr) Cur(p) D(b) H(35px) Bgz(702px) Mx(a)! W(92px)" data-reactid="12" href="https://in.finance.yahoo.com/" id="uh-logo"><b class="Hidden" data-reactid="13">Yahoo</b></a>,
#  <a class="W(0) D(ib) Whs(nw) Pos(a) Bg(#500095) C(#fff) Op(0) W(a):f Op(1):f P(5px):f" data-reactid="28" href="#Navigation">Skip to Navigation</a>,
#  <a class="W(0) D(ib) Whs(nw) Pos(a) Bg(#500095) C(#fff) Op(0) W(a):f Op(1):f P(5px):f" data-reactid="30" href="#market-summary">Skip to Market Summary</a>,
#  <a class="W(0) D(ib) Whs(nw) Pos(a) Bg(#500095) C(#fff) Op(0) W(a):f Op(1):f P(5px):f" data-reactid="32" href="#Main">Skip to Main Content</a>,
#  <a class="W(0) D(ib) Whs(nw) Pos(a) Bg(#500095) C(#fff) Op(0) W(a):f Op(1):f P(5px):f" data-reactid="34" href="#Aside">Skip to Related Content</a>,
# ...

# %%
all_links=soup.findAll("a")
for elem in all_links:
    link=str(elem.get('href'))
    print(link)
# Out:
# https://in.finance.yahoo.com/
# #Navigation
# #market-summary
# #Main
# #Aside
# https://mail.yahoo.com/?.intl=in&.lang=en-IN&.partner=none&.src=finance
# /quote/SBIN.BO?p=SBIN.BO
# /quote/SBIN.BO/key-statistics?p=SBIN.BO
# /quote/SBIN.BO/history?p=SBIN.BO
# /quote/SBIN.BO/profile?p=SBIN.BO
# /quote/SBIN.BO/financials?p=SBIN.BO
# /quote/SBIN.BO/analysis?p=SBIN.BO
# /quote/SBIN.BO/options?p=SBIN.BO
# /quote/SBIN.BO/holders?p=SBIN.BO
# /quote/SBIN.BO/sustainability?p=SBIN.BO
# /quote/SBIN.BO/news?p=SBIN.BO
# /quote/SBIN.BO/press-releases?p=SBIN.BO
# /m/730e15e2-c699-3918-b5a0-169ab2239590/ss_don%26%2339%3Bt-blame-state-banks.html
# /m/cec40fb6-0b5b-3b15-b2ce-71581ece6c6a/ss_jet-airways%26%2339%3B-lenders-hope.html
# /news/timeline-jet-airways-joy-flying-151825293.html
# /m/77145535-3235-3f26-98b6-13fc79fd9922/ss_jet-airways-stock-suffers.html
# /m/8ed0cc96-18ee-3b60-9d01-ede17fc37b07/ss_india%26%2339%3Bs-jet-airways.html
# /news/state-bank-india-cuts-benchmark-123347000.html
# ...

# %%
soup.findAll('table')
# Out:
# [<table class="W(100%)" data-reactid="8"><tbody data-reactid="9"><tr class="Bxz(bb) Bdbw(1px) Bdbs(s) Bdc($c-fuji-grey-c) H(36px) " data-reactid="10"><td class="C(black) W(51%)" data-reactid="11"><span data-reactid="12">Previous close</span></td><td class="Ta(end) Fw(600) Lh(14px)" data-reactid="13" data-test="PREV_CLOSE-value"><span class="Trsdu(0.3s) " data-reactid="14">307.45</span></td></tr><tr class="Bxz(bb) Bdbw(1px) Bdbs(s) Bdc($c-fuji-grey-c) H(36px) " data-reactid="15"><td class="C(black) W(51%)" data-reactid="16"><span data-reactid="17">Open</span></td><td class="Ta(end) Fw(600) Lh(14px)" data-reactid="18" data-test="OPEN-value"><span class="Trsdu(0.3s) " data-reactid="19">308.10</span></td></tr><tr class="Bxz(bb) Bdbw(1px) Bdbs(s) Bdc($c-fuji-grey-c) H(36px) " data-reactid="20"><td class="C(black) W(51%)" data-reactid="21"><span data-reactid="22">Bid</span></td><td class="Ta(end) Fw(600) Lh(14px)" data-reactid="23" data-test="BID-value"><span class="Trsdu(0.3s) " data-reac
# ...

# %%
len(soup.findAll('table'))
# Out:
# 2

# %%
# tr tag - defines row
# th tag - defines header
# td tag - defines a standard cell

mytable=soup.findAll('table')[0]
mytable.findAll('tr')
# Out:
# [<tr class="Bxz(bb) Bdbw(1px) Bdbs(s) Bdc($c-fuji-grey-c) H(36px) " data-reactid="10"><td class="C(black) W(51%)" data-reactid="11"><span data-reactid="12">Previous close</span></td><td class="Ta(end) Fw(600) Lh(14px)" data-reactid="13" data-test="PREV_CLOSE-value"><span class="Trsdu(0.3s) " data-reactid="14">307.45</span></td></tr>,
#  <tr class="Bxz(bb) Bdbw(1px) Bdbs(s) Bdc($c-fuji-grey-c) H(36px) " data-reactid="15"><td class="C(black) W(51%)" data-reactid="16"><span data-reactid="17">Open</span></td><td class="Ta(end) Fw(600) Lh(14px)" data-reactid="18" data-test="OPEN-value"><span class="Trsdu(0.3s) " data-reactid="19">308.10</span></td></tr>,
#  <tr class="Bxz(bb) Bdbw(1px) Bdbs(s) Bdc($c-fuji-grey-c) H(36px) " data-reactid="20"><td class="C(black) W(51%)" data-reactid="21"><span data-reactid="22">Bid</span></td><td class="Ta(end) Fw(600) Lh(14px)" data-reactid="23" data-test="BID-value"><span class="Trsdu(0.3s) " data-reactid="24">309.00 x 0</span></td></tr>,
# ...

# %%
for rows in mytable.findAll('tr'):
    data=rows.findAll('td')
    print_data=[]
    for d in data:
        print_data.append(d.text)
    print(print_data)
# Out:
# ['Previous close', '307.45']
# ['Open', '308.10']
# ['Bid', '309.00 x 0']
# ['Ask', '309.00 x 0']
# ["Day's range", '308.10 - 311.50']
# ['52-week range', '237.85 - 332.65']
# ['Volume', '2,895,175']
# ['Avg. volume', '1,198,758']

# %% [markdown]
# # Twitter API

# %% [markdown]
# <ol>
# <li>Create a Twitter user account if you do not already have one. Make sure that you have added phone number to your account</li>
# <li>Go to https://apps.twitter.com/ and log in with your Twitter user account. This step gives you a Twitter dev account under the same name as your user account.</li>
# <li>Click “Create New App”</li>
# <li>Fill out the form, agree to the terms, and click “Create your Twitter application”</li>
# <li>In the next page, click on “Keys and Access Tokens” tab, and copy your “API key” and “API secret”. Scroll down and click “Create my access token”, and copy your “Access token” and “Access token secret”.</li>
# </ol>

# %%
# !pip install twitter

# %%
from twitter import Twitter, OAuth, TwitterHTTPError, TwitterStream

# %%
# CONSUMER_KEY: ""
# CONSUMER_SECRET: ""
# ACCESS_TOKEN: ""
# ACCESS_SECRET: ""

# %%
twitter_info_file="D:/twitter_info.txt"

f=open(twitter_info_file,"r")
mykeys=[]

for line in f:
    mykeys.append(line.split(':')[1].strip())
# print(mykeys)

# %%
CONSUMER_KEY,CONSUMER_SECRET,ACCESS_TOKEN,ACCESS_SECRET=mykeys

# %% [markdown]
# you can very well manually assign values directly in the script instead of putting them in a file first

# %%
oauth = OAuth(ACCESS_TOKEN, ACCESS_SECRET, CONSUMER_KEY, CONSUMER_SECRET)
twitter= Twitter(auth=oauth)

# %%
# more details on the request parameters here :
# https://dev.twitter.com/rest/public/search
twitter.search.tweets(q='hyderabad monsoon', result_type='recent', lang='en',
                      count=3)
#can we convert these json dumps to pandas dataframes
# Out:
# {'search_metadata': {'completed_in': 0.028,
#   'count': 3,
#   'max_id': 1124224429414801408,
#   'max_id_str': '1124224429414801408',
#   'next_results': '?max_id=1123650486329016319&q=hyderabad%20monsoon&lang=en&count=3&include_entities=1&result_type=recent',
#   'query': 'hyderabad+monsoon',
#   'refresh_url': '?since_id=1124224429414801408&q=hyderabad%20monsoon&lang=en&result_type=recent&include_entities=1',
#   'since_id': 0,
#   'since_id_str': '0'},
#  'statuses': [{'contributors': None,
#    'coordinates': None,
#    'created_at': 'Fri May 03 08:09:25 +0000 2019',
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'urls': [{'display_url': 'timesofindia.indiatimes.com/city/hyderabad…',
#       'expanded_url': 'https://timesofindia.indiatimes.com/city/hyderabad/netizens-sight-yeti-footprints-on-city-roads-across-country/articleshow/69152765.cms',
#       'indices': [110, 133],
#       'url': 'https://t.co/CJrQmJ9p43'}],
#     'user_mentions': []},
# ...

# %%
twitter.search.tweets(q='ipl', result_type='recent', lang='en',
                      count=3)
# Out:
# {'search_metadata': {'completed_in': 0.032,
#   'count': 3,
#   'max_id': 1124906010819194880,
#   'max_id_str': '1124906010819194880',
#   'next_results': '?max_id=1124905995736453120&q=ipl&lang=en&count=3&include_entities=1&result_type=recent',
#   'query': 'ipl',
#   'refresh_url': '?since_id=1124906010819194880&q=ipl&lang=en&result_type=recent&include_entities=1',
#   'since_id': 0,
#   'since_id_str': '0'},
#  'statuses': [{'contributors': None,
#    'coordinates': None,
#    'created_at': 'Sun May 05 05:17:47 +0000 2019',
#    'entities': {'hashtags': [{'indices': [59, 67], 'text': 'VIVOIPL'}],
#     'symbols': [],
#     'urls': [],
#     'user_mentions': [{'id': 15639696,
#       'id_str': '15639696',
#       'indices': [3, 7],
#       'name': 'IndianPremierLeague',
#       'screen_name': 'IPL'},
#      {'id': 70931004,
#       'id_str': '70931004',
#       'indices': [89, 99],
#       'name': 'Royal Challengers',
#       'screen_name': 'RCBTweets'}]},
# ...

# %% [markdown]
# ### Twitter Stream

# %%
import json

# %%
twitter_stream = TwitterStream(auth=oauth)

# %%
iterator = twitter_stream.statuses.sample()

tweet_count = 10
for tweet in iterator:
    tweet_count -= 1
    
    print(json.dumps(tweet, indent=4) )
       
    if tweet_count <= 0:
        break
# Out:
# {
#     "created_at": "Sun May 05 05:22:23 +0000 2019",
#     "id": 1124907169650860032,
#     "id_str": "1124907169650860032",
#     "text": "@nishino__ke W\u30c1\u30e3\u30f3\u30b9\u3078\u306e\u3054\u53c2\u52a0\u3042\u308a\u304c\u3068\u3046\u3054\u3056\u3044\u307e\u3059\u2728\n\u62bd\u9078\u7d50\u679c\u306f\u52d5\u753b\u3092\u898b\u3066\u306d\uff01\ud83c\udf8a\n\n#\u4ee4\u548c\u6700\u521d\u306e\u5922 \u30ad\u30e3\u30f3\u30da\u30fc\u30f3\u3082\u3001\u5fd8\u308c\u305a\u306b\u53c2\u52a0\u3057\u3066\u306d\ud83c\udfb6\n\n\u8a73\u7d30\u306f\u3001\u56fa\u5b9a\u30c4\u30a4\u30fc\u30c8\u3092\u30c1\u30a7\u30c3\u30af\ud83d\udd0e\n\n\u25bc\u30ad\u30e3\u30f3\u30da\u30fc\u30f3\u30b5\u30a4\u30c8\u306f\u3053\u3061\u3089\u2026 https://t.co/Wq4OqhZUY5",
#     "display_text_range": [
#         0,
#         140
#     ],
#     "source": "<a href=\"https://products.comnico.jp/atelu/jp\" rel=\"nofollow\">ATELU for Twitter</a>",
#     "truncated": true,
#     "in_reply_to_status_id": null,
# ...

# %%
print(json.dumps(hyd_trend, indent=2))

# %% [markdown]
# ### Tracking a specific keyword in stream

# %%
#TAKES A LONG TIME TO RUN
iterator = twitter_stream.statuses.filter(track="Mumbai Monsoon", language="en")
tweet_count = 3
for tweet in iterator:
    tweet_count -= 1
    
    print(json.dumps(tweet, indent=2) )
       
    if tweet_count <= 0:
        break
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-124-5712e2ffaa1b> in <module>()
#       2 iterator = twitter_stream.statuses.filter(track="Mumbai Monsoon", language="en")
#       3 tweet_count = 3
# ----> 4 for tweet in iterator:
#       5     tweet_count -= 1
#       6
#
# C:\Users\DELL\Anaconda3\lib\site-packages\twitter\stream.py in __iter__(self)
#     175             # Decode all the things:
#     176             try:
# --> 177                 data = sock_reader.read()
#     178             except SSLError:
#     179                 yield Hangup
#
# C:\Users\DELL\Anaconda3\lib\site-packages\twitter\stream.py in read(self)
#     131     def read(self):
#     132         try:
# --> 133             ready_to_read = select.select([self.sock], [], [], self.sock_timeout)[0]
#     134             if ready_to_read:
#     135                 return self.sock.read()
#
# ...

# %% [markdown]
# ### trends API

# %%
world_trends = twitter.trends.available()
world_trends[1:3]
# Out:
# [{'country': 'Canada',
#   'countryCode': 'CA',
#   'name': 'Winnipeg',
#   'parentid': 23424775,
#   'placeType': {'code': 7, 'name': 'Town'},
#   'url': 'http://where.yahooapis.com/v1/place/2972',
#   'woeid': 2972},
#  {'country': 'Canada',
#   'countryCode': 'CA',
#   'name': 'Ottawa',
#   'parentid': 23424775,
#   'placeType': {'code': 7, 'name': 'Town'},
#   'url': 'http://where.yahooapis.com/v1/place/3369',
#   'woeid': 3369}]

# %%
world_trends[1].get('woeid')
# Out:
# 2972

# %%
df = pd.DataFrame()
for i in range(len(world_trends)):
    df.loc[i,'Country'] = world_trends[i].get('country')
    df.loc[i,'Name'] = world_trends[i].get('name')
    df.loc[i,'WOEID'] = world_trends[i].get('woeid')

df

# %%
df[df.Country=='India']
# Out:
#     Country       Name       WOEID
# 300   India     Nagpur   2282863.0
# 301   India    Lucknow   2295377.0
# 302   India     Kanpur   2295378.0
# 303   India      Patna   2295381.0
# 304   India     Ranchi   2295383.0
# 305   India    Kolkata   2295386.0
# 306   India   Srinagar   2295387.0
# 307   India   Amritsar   2295388.0
# 308   India     Jaipur   2295401.0
# 309   India  Ahmedabad   2295402.0
# 310   India     Rajkot   2295404.0
# 311   India      Surat   2295405.0
# 312   India     Bhopal   2295407.0
# 313   India     Indore   2295408.0
# 314   India      Thane   2295410.0
# 315   India     Mumbai   2295411.0
# 316   India       Pune   2295412.0
# 317   India  Hyderabad   2295414.0
# 318   India  Bangalore   2295420.0
# 319   India    Chennai   2295424.0
# 400   India      Delhi  20070458.0
# 424   India      India  23424848.0

# %%
# http://woeid.rosselliot.co.nz/lookup/
hyd_trend=twitter.trends.place(_id = 2295411)

# %%
print(json.dumps(hyd_trend, indent=2))
# Out:
# [
#   {
#     "trends": [
#       {
#         "name": "#JaiShriRam",
#         "url": "http://twitter.com/search?q=%23JaiShriRam",
#         "promoted_content": null,
#         "query": "%23JaiShriRam",
#         "tweet_volume": null
#       },
#       {
#         "name": "#WorldLaughterDay",
#         "url": "http://twitter.com/search?q=%23WorldLaughterDay",
#         "promoted_content": null,
#         "query": "%23WorldLaughterDay",
#         "tweet_volume": null
#       },
#       {
#         "name": "#MrLocalTrailer",
#         "url": "http://twitter.com/search?q=%23MrLocalTrailer",
#         "promoted_content": null,
#         "query": "%23MrLocalTrailer",
#         "tweet_volume": 10602
#       },
#       {
#         "name": "#SundayThoughts",
#         "url": "http://twitter.com/search?q=%23SundayThoughts",
#         "promoted_content": null,
#         "query": "%23SundayThoughts",
#         "tweet_volume": null
#       },
#       {
#         "name": "#SundayMorning",
# ...

# %% [markdown]
# ### User API

# %%
# Get a list of followers of a particular user
twitter.followers.ids(screen_name="karthik")
# Out:
# {'ids': [1044898730191667200,
#   1122129492195983361,
#   1122123508031508480,
#   1117639092684988417,
#   1120652032312922112,
#   1116224458325278720,
#   621885376,
#   1116669965791219712,
#   1115823187898580992,
#   1115412427548631041,
#   1012893226385096707,
#   1108637192371535872,
#   85965752,
#   1107609109409390592,
#   1106893833709764609,
#   1011078540647809025,
#   1103631273891749888,
#   959116853955235840,
#   2322006708,
#   107054756,
#   1059700993502466048,
#   1097002817233989632,
#   1095542361965219841,
#   1094257748433424385,
#   1094551762302754816,
#   1094164459197739008,
#   910752992105709568,
#   1083071859615182849,
#   500403863,
#   1083651314234548226,
#   1074857667796103168,
#   1064029728162504704,
#   147858554,
#   1073480577498664962,
#   1068113364532944897,
#   1065441956153581569,
#   1041227250534821889,
#   1065214420500934656,
#   1064061394167840769,
#   1062631836856320001,
#   1061946726926319616,
#   836609285496979456,
# ...

# %%
twitter.statuses.user_timeline(screen_name="karthik")
# Out:
# [{'contributors': None,
#   'coordinates': None,
#   'created_at': 'Sat May 04 12:41:14 +0000 2019',
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'urls': [],
#    'user_mentions': [{'id': 227363436,
#      'id_str': '227363436',
#      'indices': [0, 9],
#      'name': 'Mehul Ved',
#      'screen_name': 'mehulved'}]},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 1124655222016503808,
#   'id_str': '1124655222016503808',
#   'in_reply_to_screen_name': 'mehulved',
#   'in_reply_to_status_id': 1124654671451312129,
#   'in_reply_to_status_id_str': '1124654671451312129',
#   'in_reply_to_user_id': 227363436,
#   'in_reply_to_user_id_str': '227363436',
#   'is_quote_status': False,
#   'lang': 'en',
#   'place': None,
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
# ...

# %% [markdown]
# # Exercises

# %% [markdown]
# * find out how to save files to your own machine using urllib
# * find out how to convert json dumps to pandas dataframes
